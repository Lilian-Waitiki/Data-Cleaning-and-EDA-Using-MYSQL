# %% [markdown]
# # Integrated Project 2
# **Clustering Data To Unveil Maji Ndogo's Water Crisis.**

# %% [markdown]
# ## Introduction
# **Setting the stage for our data exploration journey.**

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:lilian80@localhost:3306/md_water_servicesds
# Out:
# 'Connected: root@md_water_servicesds'

# %%
# %%sql
# SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 8 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',)]

# %% [markdown]
# ## 1. Cleaning Our Data
# **Updating employee data.**

# %% [markdown]
# ### 1.5. Add email Addresses
# Ok, bring up the employee table. It has info on all of our workers, but note that the email addresses have not been added. We will have to send
# them reports and figures, so let's update it. Luckily the emails for our department are easy: `first_name.last_name@ndogowater.gov`.

# %%
# %%sql
# SELECT * FROM employee Limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900', 'malachi.mavuso@ndogowater.gov', '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640', 'cheche.buhle@ndogowater.gov', '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor')]

# %%
# %%sql
# SELECT
#     employee_name,
#     lower(REPLACE(employee_name, ' ', '.')) AS LowerFullName,
#     CONCAT(lower(REPLACE(employee_name, ' ', '.')),'@ndogowater.gov') AS Email
# FROM employee
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('Amara Jengo', 'amara.jengo', 'amara.jengo@ndogowater.gov'),
#  ('Bello Azibo', 'bello.azibo', 'bello.azibo@ndogowater.gov'),
#  ('Bakari Iniko', 'bakari.iniko', 'bakari.iniko@ndogowater.gov'),
#  ('Malachi Mavuso', 'malachi.mavuso', 'malachi.mavuso@ndogowater.gov'),
#  ('Cheche Buhle', 'cheche.buhle', 'cheche.buhle@ndogowater.gov')]

# %% [markdown]
# ### 1.7. UPDATE email column
# UPDATE the email column this time with the email addresses

# %%
# %%sql
# UPDATE employee
# SET email = CONCAT(LOWER(REPLACE(employee_name, ' ', '.')),'@ndogowater.gov')
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 56 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "UPDATE employee \nSET email = CONCAT(LOWER(REPLACE(employee_name, ' ', '.')),'@ndogowater.gov')\n")
#
# File ~\anaconda3\envs\SQL_packages\Lib\site-packages\IPython\core\interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\envs\SQL_packages\Lib\site-packages\sql\magic.py:95, in SqlMagic.execute(self, line, cell, local_ns)
#      92     return self._persist_dataframe(parsed['sql'], conn, user_ns)
#      94 try:
# ---> 95     result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      97     if result is not None and not isinstance(result, str) and self.column_local_vars:
#      98         #Instead of returning values, set variables directly in the
#      99         #users namespace. Variable names given by column names
#     101         if self.autopandas:
#
# File ~\anaconda3\envs\SQL_packages\Lib\site-packages\sql\run.py:344, in run(conn, sql, config, user_namespace)
#     342     if result and config.feedback:
#     343         print(interpret_rowcount(result.rowcount))
# --> 344 resultset = ResultSet(result, statement, config)
#     345 if config.autopandas:
#     346     return resultset.DataFrame()
#
# File ~\anaconda3\envs\SQL_packages\Lib\site-packages\sql\run.py:107, in ResultSet.__init__(self, sqlaproxy, sql, config)
#     106 def __init__(self, sqlaproxy, sql, config):
# --> 107     self.keys = sqlaproxy.keys()
#     108     self.sql = sql
#     109     self.config = config
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\result.py:700, in _WithKeys.keys(self)
#     683 def keys(self):
#     684     """Return an iterable view which yields the string keys that would
#     685     be represented by each :class:`.Row`.
#     686
#    (...)
#     698
#     699     """
# --> 700     return self._metadata.keys
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\cursor.py:1201, in _NoResultMetaData.keys(self)
#    1199 @property
#    1200 def keys(self):
# -> 1201     self._we_dont_return_rows()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\cursor.py:1178, in _NoResultMetaData._we_dont_return_rows(self, err)
#    1177 def _we_dont_return_rows(self, err=None):
# -> 1178     util.raise_(
#    1179         exc.ResourceClosedError(
#    1180             "This result object does not return rows. "
#    1181             "It has been closed automatically."
#    1182         ),
#    1183         replace_context=err,
#    1184     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# SELECT* FROM employee;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 56 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900', 'malachi.mavuso@ndogowater.gov', '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640', 'cheche.buhle@ndogowater.gov', '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor'),
#  (5, 'Zuriel Matembo', '+99034075111', 'zuriel.matembo@ndogowater.gov', '26 Bahari Ya Faraja Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (6, 'Deka Osumare', '+99379364631', 'deka.osumare@ndogowater.gov', '104 Kenyatta Street', 'Akatsi', 'Rural', 'Field Surveyor'),
#  (7, 'Lalitha Kaburi', '+99681623240', 'lalitha.kaburi@ndogowater.gov', '145 Sungura Amanpour Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (8, 'Enitan Zuri', '+99248509202', 'enitan.zuri@ndogowater.gov', '117 Kampala Road', 'Hawassa', 'Zanzibar', 'Field Surveyor'),
#  (10, 'Farai Nia', '+99570082739', 'farai.nia@ndogowater.gov', '33 Angélique Kidjo Avenue', 'Amanzi', 'Dahabu', 'Field Surveyor'),
#  (12, 'Gamba Shani', '+99438283153', 'gamba.shani@ndogowater.gov', '38 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (14, 'Harith Nyota', '+99917230124', 'harith.nyota@ndogowater.gov', '42 Malabo Drive', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (16, 'Isoke Amani', '+99313603182', 'isoke.amani@ndogowater.gov', '55 Fennec Way', 'Sokoto', 'Rural', 'Field Surveyor'),
#  (18, 'Jengo Tumaini', '+99820596465', 'jengo.tumaini@ndogowater.gov', '17 Port Harcourt Boulevard', 'Akatsi', 'Kintampo', 'Field Surveyor'),
#  (20, 'Kunto Asha', '+99176320477', 'kunto.asha@ndogowater.gov', '30 Nyoka Achebe Street', 'Amanzi', 'Dahabu', 'Field Surveyor'),
#  (22, 'Lesedi Kofi', '+99611183730', 'lesedi.kofi@ndogowater.gov', '52 Moroni Avenue', 'Sokoto', 'Rural', 'Field Surveyor'),
#  (24, 'Makena Thabo', '+99690308755', 'makena.thabo@ndogowater.gov', '81 Rhodes Street', 'Hawassa', 'Rural', 'Field Surveyor'),
#  
#  (105, 'Xola Inaya', '+99231569847', 'xola.inaya@ndogowater.gov', '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Engineer'),
#  (108, 'Yewande Jengo', '+99123456978', 'yewande.jengo@ndogowater.gov', '25 Selassie Drive', 'Amanzi', 'Rural', 'Construction Manager'),
#  (110, 'Zuri Kofi', '+99412356789', 'zuri.kofi@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Graphic Designer')]

# %%
# %%sql
# SELECT
#     LENGTH(phone_number) as PhoneLength,
#     TRIM(phone_number) AS TrimmedPhone,
#     LENGTH(TRIM(phone_number)) TrimmedLength
# FROM employee
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [(12, '+99637993287', 12),
#  (12, '+99643864786', 12),
#  (12, '+99222599041', 12),
#  (12, '+99945849900', 12),
#  (12, '+99381679640', 12)]

# %%
# %%sql
# UPDATE employee
# SET phone_number = TRIM(phone_number)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 56 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'UPDATE employee \nSET phone_number = TRIM(phone_number)\n')
#
# File ~\anaconda3\envs\SQL_packages\Lib\site-packages\IPython\core\interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\envs\SQL_packages\Lib\site-packages\sql\magic.py:95, in SqlMagic.execute(self, line, cell, local_ns)
#      92     return self._persist_dataframe(parsed['sql'], conn, user_ns)
#      94 try:
# ---> 95     result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      97     if result is not None and not isinstance(result, str) and self.column_local_vars:
#      98         #Instead of returning values, set variables directly in the
#      99         #users namespace. Variable names given by column names
#     101         if self.autopandas:
#
# File ~\anaconda3\envs\SQL_packages\Lib\site-packages\sql\run.py:344, in run(conn, sql, config, user_namespace)
#     342     if result and config.feedback:
#     343         print(interpret_rowcount(result.rowcount))
# --> 344 resultset = ResultSet(result, statement, config)
#     345 if config.autopandas:
#     346     return resultset.DataFrame()
#
# File ~\anaconda3\envs\SQL_packages\Lib\site-packages\sql\run.py:107, in ResultSet.__init__(self, sqlaproxy, sql, config)
#     106 def __init__(self, sqlaproxy, sql, config):
# --> 107     self.keys = sqlaproxy.keys()
#     108     self.sql = sql
#     109     self.config = config
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\result.py:700, in _WithKeys.keys(self)
#     683 def keys(self):
#     684     """Return an iterable view which yields the string keys that would
#     685     be represented by each :class:`.Row`.
#     686
#    (...)
#     698
#     699     """
# --> 700     return self._metadata.keys
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\cursor.py:1201, in _NoResultMetaData.keys(self)
#    1199 @property
#    1200 def keys(self):
# -> 1201     self._we_dont_return_rows()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\cursor.py:1178, in _NoResultMetaData._we_dont_return_rows(self, err)
#    1177 def _we_dont_return_rows(self, err=None):
# -> 1178     util.raise_(
#    1179         exc.ResourceClosedError(
#    1180             "This result object does not return rows. "
#    1181             "It has been closed automatically."
#    1182         ),
#    1183         replace_context=err,
#    1184     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# SELECT
#     LENGTH (phone_number) as new_phone_length
# FROM employee
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3 rows affected.
# [(12,), (12,), (12,)]

# %% [markdown]
# ## 2. Honouring the workers.
# **Finding our best.**

# %% [markdown]
# ### 2.8. Employees in each town
# Before we dive into the analysis, let's get you warmed up a bit!
# Let's have a look at where our employees live.
# Use the `employee` table to count how many of our employees live in each town. Think carefully about what function we should use and how we
# should aggregate the data.

# %%
# %%sql
# SELECT
#     town_name,
#     COUNT(employee_name) as num_employees
# FROM employee
# GROUP BY town_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 9 rows affected.
# [('Ilanga', 3),
#  ('Rural', 29),
#  ('Lusaka', 4),
#  ('Zanzibar', 4),
#  ('Dahabu', 6),
#  ('Kintampo', 1),
#  ('Harare', 5),
#  ('Yaounde', 1),
#  ('Serowe', 3)]

# %% [markdown]
# ### 10. Employees by locations visited
# Let's first look at the number of records each employee collected. So find the correct table, figure out what function to use and how to group, order
# and limit the results to only see the top 3 employee_ids with the highest number of locations visited.

# %%
# %%sql
# SELECT
#     assigned_employee_id,
#     COUNT(visit_count) as number_of_visits
# FROM visits
# GROUP BY assigned_employee_id
# ORDER BY 2 DESC
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3 rows affected.
# [(1, 3708), (30, 3676), (34, 3539)]

# %% [markdown]
# Make a note of the top 3 `assigned_employee_id` and use them to create a query that looks up the employee's info. Since you're a pro at finding
# stuff in a database now, you can figure this one out. You should have a column of` name` s,` email addresse`s and` phone number`s for our top dogs.

# %%
# %%sql
# SELECT
#     assigned_employee_id,
#     employee_name,
#     email,
#     phone_number
# FROM employee
# WHERE assigned_employee_id IN (1,30,34);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3 rows affected.
# [(1, 'Bello Azibo', 'bello.azibo@ndogowater.gov', '+99643864786'),
#  (30, 'Pili Zola', 'pili.zola@ndogowater.gov', '+99822478933'),
#  (34, 'Rudo Imani', 'rudo.imani@ndogowater.gov', '+99046972648')]

# %% [markdown]
# ## 3. Analysing Locations
# **Understanding where the water sources are.**

# %% [markdown]
# ### 3.11. Number of records per town & province
# Looking at the location table, let’s focus on the `province_name`, `town_name` and `location_type` to understand where the water sources are in
# Maji Ndogo.
# Create a query that counts the number of records per town

# %%
# %%sql
# SELECT * FROM location LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3 rows affected.
# [('AkHa00000', '2 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00001', '10 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00002', '9 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban')]

# %%
# %%sql
# SELECT
#     town_name,
#     COUNT(town_name) as records_per_town
# FROM location
# GROUP BY town_name
# ORDER BY 2 DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('Rural', 23740),
#  ('Harare', 1650),
#  ('Amina', 1090),
#  ('Lusaka', 1070),
#  ('Mrembo', 990)]

# %% [markdown]
# Now count the records per province

# %%
# %%sql
# SELECT
#     province_name,
#     COUNT(province_name) as records_per_province
# FROM location
# GROUP BY province_name
# ORDER BY 2 DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('Kilimani', 9510),
#  ('Akatsi', 8940),
#  ('Sokoto', 8220),
#  ('Amanzi', 6950),
#  ('Hawassa', 6030)]

# %% [markdown]
# ### 3.12. Aggregate Functions
#
# Can you find a way to do the following:
#
# 1. Create a result set showing:
#    - `province_name`.
#    - `town_name`.
#    - An aggregated count of records for each town (consider naming this `records_per_town`).
#    - Ensure your data is grouped by both `province_name` and `town_name`.
# 2. Order your results primarily by province_name. Within each province, further sort the towns by their record counts in descending order.

# %%
# %%sql
# SELECT
#     province_name,
#     town_name,
#     COUNT(town_name) as records_per_town
# FROM location
# GROUP BY province_name, town_name
# ORDER BY province_name, town_name DESC
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 10 rows affected.
# [('Akatsi', 'Rural', 6290),
#  ('Akatsi', 'Lusaka', 1070),
#  ('Akatsi', 'Kintampo', 780),
#  ('Akatsi', 'Harare', 800),
#  ('Amanzi', 'Rural', 3100),
#  ('Amanzi', 'Pwani', 520),
#  ('Amanzi', 'Dahabu', 930),
#  ('Amanzi', 'Bello', 400),
#  ('Amanzi', 'Asmara', 930),
#  ('Amanzi', 'Amina', 670)]

# %% [markdown]
# Finally, look at the number of records for each location type

# %%
# %%sql
# SELECT
#     location_type,
#     COUNT(location_type) as num_sources
# FROM location
# GROUP BY location_type;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 2 rows affected.
# [('Urban', 15910), ('Rural', 23740)]

# %%
# %%sql
# SELECT
#     ROUND(23740 / (15910 + 23740) * 100) as Rural_percentage,
#     ROUND(15910 / (15910 + 23740) * 100) as Urban_percentage
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 1 rows affected.
# [(Decimal('60'), Decimal('40'))]

# %% [markdown]
# ## 4. Diving into the sources
# **Seeing the scope of the problem.**

# %%
# %%sql
# SELECT * FROM water_source LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('AkHa00000224', 'tap_in_home', 956),
#  ('AkHa00001224', 'tap_in_home_broken', 930),
#  ('AkHa00002224', 'tap_in_home_broken', 486),
#  ('AkHa00003224', 'well', 364),
#  ('AkHa00004224', 'tap_in_home_broken', 942)]

# %% [markdown]
# ### 4.15 Exploring the `water_source` table
# The way I look at this table; we have access to different water source types and the number of people using each source.
# These are the questions that I am curious about.
# 1. How many people did we survey in total?
# 2. How many wells, taps and rivers are there?
# 3. How many people share particular types of water sources on average?
# 4. How many people are getting water from each type of source?

# %%
# %%sql
# # 1.how many people we surveyed in total
# SELECT
# SUM(number_of_people_served) as total_people_served
# FROM water_source;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 1 rows affected.
# [(Decimal('27628140'),)]

# %%
# %%sql
# ## 2.How many wells, taps, and rivers are there?
# SELECT
#     type_of_water_source,
#     COUNT(type_of_water_source) as number_of_sources
# FROM water_source
# GROUP BY type_of_water_source;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('tap_in_home', 7265),
#  ('tap_in_home_broken', 5856),
#  ('well', 17383),
#  ('shared_tap', 5767),
#  ('river', 3379)]

# %%
# %%sql
# # 3.How many people share particular types of water sources on average?
# SELECT
#     type_of_water_source,
#     ROUND(AVG(number_of_people_served)) as average_people_per_source
# FROM water_source
# GROUP BY type_of_water_source;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('tap_in_home', Decimal('644')),
#  ('tap_in_home_broken', Decimal('649')),
#  ('well', Decimal('279')),
#  ('shared_tap', Decimal('2071')),
#  ('river', Decimal('699'))]

# %% [markdown]
# These results are telling us that 644 people share a `tap_in_home` on average.
# <br>Does that make sense? No it doesn’t, right?
# <br>A few important things that apply to `tap_in_home` and `broken_tap_in_home` - The surveyors combined the data of many households together and added this as a single tap record, but each household actually has its own tap. In addition to this, there is an average of
# 6 people living in a home. So 6 people actually share 1 tap (not 644).This means that 1 `tap_in_home` actually represents 644 ÷ 6 = ± 100 taps.

# %%
# %%sql
# # 4. How many people are getting water from each type of source?
# SELECT
#     type_of_water_source,
#     SUM(number_of_people_served) as population_served
# FROM water_source
# GROUP BY type_of_water_source
# ORDER BY 2 DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('shared_tap', Decimal('11945272')),
#  ('well', Decimal('4841724')),
#  ('tap_in_home', Decimal('4678880')),
#  ('tap_in_home_broken', Decimal('3799720')),
#  ('river', Decimal('2362544'))]

# %% [markdown]
# ### 4.19. Percentage of People served per source
# It's a little hard to comprehend these numbers, but you can see that one of these is dominating. To make it a bit simpler to interpret, let's use
# percentages. First, we need the total number of citizens then use the result of that and divide each of the` SUM(number_of_people_served`) by
# that number, times 100, to get percentages.

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     ROUND(SUM(number_of_people_served)/27628140 * 100) as percentage_people_per_source
# FROM water_source
# GROUP BY type_of_water_source
# ORDER BY 2 DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('shared_tap', Decimal('43')),
#  ('well', Decimal('18')),
#  ('tap_in_home', Decimal('17')),
#  ('tap_in_home_broken', Decimal('14')),
#  ('river', Decimal('9'))]

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     ROUND(SUM(number_of_people_served)/(
#           SELECT
#           SUM(number_of_people_served)
#           FROM water_source) * 100) as percentage_people_per_source
# FROM water_source
# GROUP BY type_of_water_source
# ORDER BY 2 DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('shared_tap', Decimal('43')),
#  ('well', Decimal('18')),
#  ('tap_in_home', Decimal('17')),
#  ('tap_in_home_broken', Decimal('14')),
#  ('river', Decimal('9'))]

# %% [markdown]
# 43% of our people are using shared taps in their communities, and on average, we saw earlier, that 2000 people share one `shared_tap`.
# By adding `tap_in_home` and `tap_in_home_broken` together, we see that 31% of people have water infrastructure installed in their homes, but 45%
# (14/31) of these taps are not working! This isn't the tap itself that is broken, but rather the infrastructure like treatment plants, reservoirs, pipes, and pumps that serve these homes that are broken.
# 18% of people are using `wells`. But only 4916 out of 17383 are clean = 28% (from last week).

# %% [markdown]
# ## 5. Start a solution
# **Thinking about how we can repair.**

# %% [markdown]
# ### 5.23 Window Function

# %% [markdown]
# At some point, we will have to fix or improve all of the infrastructure, so we should start thinking about how we can make a data-driven decision and
# how to do it. I think a simple approach is to fix the things that affect most people first. We will need the following columns:
# - Type of sources -- Easy
# - Total people served grouped by the types -- We did that earlier, so that's easy too.
# - A rank based on the total people served, grouped by the types -- A little harder.

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     SUM(number_of_people_served) as population_served,
#     RANK() OVER(
#         ORDER BY SUM(number_of_people_served) DESC) as rank_by_population
# FROM water_source
# GROUP BY type_of_water_source;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('shared_tap', Decimal('11945272'), 1),
#  ('well', Decimal('4841724'), 2),
#  ('tap_in_home', Decimal('4678880'), 3),
#  ('tap_in_home_broken', Decimal('3799720'), 4),
#  ('river', Decimal('2362544'), 5)]

# %% [markdown]
# Ok, so we should fix shared taps first, then wells, and so on. But the next question is, which shared taps or wells should be fixed first? We can use
# the same logic; the most used sources should really be fixed first.

# %% [markdown]
# ### 5.24. Finding the Most Used Sources
# So create a query to do this, and keep these requirements in mind:
# 1. The sources within each type should be assigned a rank.
# 2. Limit the results to only improvable sources.
# 3. Think about how to partition, filter and order the results set.
# 4. Order the results to see the top of the list.

# %%
# %%sql
# SELECT
#     source_id,
#     type_of_water_source,
#     number_of_people_served,
#     RANK() OVER(
#         PARTITION BY type_of_water_source ORDER BY number_of_people_served DESC) as priority_rank
# FROM water_source
# WHERE type_of_water_source NOT IN ('tap_in_home')
# LIMIT 3385;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3385 rows affected.
# [('SoRu34798224', 'river', 998, 1),
#  ('SoRu35837224', 'river', 998, 1),
#  ('SoRu36238224', 'river', 998, 1),
#  ('SoRu36791224', 'river', 998, 1),
#  ('SoRu36880224', 'river', 998, 1),
#  ('SoRu38142224', 'river', 998, 1),
#  ('SoRu37756224', 'river', 998, 1),
#  ('SoMa33775224', 'river', 998, 1),
#  ('KiRu30353224', 'river', 998, 1),
#  ('SoIl32972224', 'river', 998, 1),
#  ('KiZu31236224', 'river', 998, 1),
#  ('KiRu28591224', 'river', 998, 1),
#  ('KiMr25030224', 'river', 998, 1),
#  ('KiRu25603224', 'river', 996, 14),
#  ('KiRu26027224', 'river', 996, 14),
#  ('KiRu30532224', 'river', 996, 14),
#  ('SoRu36229224', 'river', 996, 14),
#  ('AkRu08053224', 'river', 996, 14),
#  ('AmAb09070224', 'river', 996, 14),
#  ('SoKo33179224', 'river', 994, 20),
#  ('HaRu20469224', 'river', 994, 20),
#  ('KiRu28404224', 'river', 994, 20),
#  ('KiRu27661224', 'river', 994, 20),
#  ('SoRu36506224', 'river', 994, 20),
#  ('SoRu37912224', 'river', 994, 20),
#  ('SoRu35192224', 'river', 992, 26),
#  ('SoRu36076224', 'river', 992, 26),
#  ('SoRu37032224', 'river', 992, 26),
#  ('SoMa33620224', 'river', 992, 26),
#  ('AkRu04142224', 'river', 992, 26),
#  ('SoRu38498224', 'river', 992, 26),
#  ('SoRu39029224', 'river', 992, 26),
#  ('AmRu13795224', 'river', 992, 26),
#  ('KiRu28002224', 'river', 992, 26),
#  ('KiRu27266224', 'river', 992, 26),
#  ('KiRu29844224', 'river', 992, 26),
#  ('SoRu37904224', 'river', 990, 37),
#  ('SoRu37158224', 'river', 990, 37),
#  ('SoRu37004224', 'river', 990, 37),
#  ('KiRu25651224', 'river', 990, 37),
#  ('SoIl32652224', 'river', 990, 37),
#  ('HaRu17065224', 'river', 990, 37),
#  ('AkRu08333224', 'river', 990, 37),
#  ('AkRu05337224', 'river', 988, 44),
#  ('AkRu06935224', 'river', 988, 44),
#  ('KiAm22552224', 'river', 988, 44),
#  ('KiRu28398224', 'river', 988, 44),
#  ('KiRu28604224', 'river', 988, 44),
#  ('AmAs10139224', 'river', 988, 44),
#  ('AmDa11775224', 'river', 988, 44),
#  ('SoRu37223224', 'river', 988, 44),
#  ('SoRu36894224', 'river', 988, 44),
#  ('SoKo33302224', 'river', 988, 44),
#  ('SoMa34112224', 'river', 988, 44),
#  ('SoKo33275224', 'river', 988, 44),
#  ('SoCh32068224', 'river', 988, 44),
#  ('HaRu20007224', 'river', 988, 44),
#  ('HaRu19708224', 'river', 986, 58),
#  ('KiMr24403224', 'river', 986, 58),
#  ('KiHa23332224', 'river', 986, 58),
#  ('AkRu03607224', 'river', 986, 58),
#  ('KiZu30757224', 'river', 986, 58),
#  ('SoBa31824224', 'river', 986, 58),
#  ('SoMa33961224', 'river', 986, 58),
#  ('SoBa31788224', 'river', 986, 58),
#  ('SoRu36044224', 'river', 986, 58),
#  ('SoRu37968224', 'river', 986, 58),
#  ('SoRu35464224', 'river', 986, 58),
#  ('SoRu36871224', 'river', 986, 58),
#  ('SoRu35151224', 'river', 986, 58),
#  ('SoRu38054224', 'river', 984, 71),
#  ('SoRu37388224', 'river', 984, 71),
#  ('SoRu35074224', 'river', 984, 71),
#  ('KiMr24365224', 'river', 984, 71),
#  ('AmAm09565224', 'river', 984, 71),
#  ('SoRu39564224', 'river', 984, 71),
#  ('SoRu39120224', 'river', 984, 71),
#  ('SoRu38884224', 'river', 984, 71),
#  ('HaRu20269224', 'river', 984, 71),
#  ('SoKo33516224', 'river', 984, 71),
#  ('SoKo33278224', 'river', 984, 71),
#  ('AmRu13767224', 'river', 984, 71),
#  ('AmRu13651224', 'river', 982, 83),
#  ('SoRu38692224', 'river', 982, 83),
#  ('SoRu39206224', 'river', 982, 83),
#  ('AkRu07053224', 'river', 982, 83),
#  ('SoRu36666224', 'river', 982, 83),
#  ('SoRu36065224', 'river', 982, 83),
#  ('SoRu38006224', 'river', 982, 83),
#  ('SoRu37046224', 'river', 982, 83),
#  ('AmBe11055224', 'river', 982, 83),
#  ('AmDa11856224', 'river', 982, 83),
#  ('SoBa31517224', 'river', 982, 83),
#  ('HaRu19782224', 'river', 982, 83),
#  ('HaYa21524224', 'river', 982, 83),
#  ('SoRu34875224', 'river', 980, 96),
#  ('SoRu36036224', 'river', 980, 96),
#  ('KiAm22020224', 'river', 980, 96),
#  ('AmRu13667224', 'river', 980, 96),
#  ('AkRu06243224', 'river', 980, 96),
#  ('AkRu08369224', 'river', 980, 96),
#  ('AkRu06666224', 'river', 980, 96),
#  ('SoBa31654224', 'river', 980, 96),
#  ('SoCh32266224', 'river', 978, 104),
#  ('SoKo33083224', 'river', 978, 104),
#  ('AmRu13901224', 'river', 978, 104),
#  ('SoRu37536224', 'river', 978, 104),
#  ('SoRu37761224', 'river', 978, 104),
#  ('SoRu36311224', 'river', 978, 104),
#  ('SoRu37881224', 'river', 978, 104),
#  ('HaSe21297224', 'river', 978, 104),
#  ('AkRu07584224', 'river', 978, 104),
#  ('AkLu02389224', 'river', 978, 104),
#  ('SoRu35432224', 'river', 976, 114),
#  ('SoRu35138224', 'river', 976, 114),
#  ('SoRu34768224', 'river', 976, 114),
#  ('SoRu38330224', 'river', 976, 114),
#  ('SoRu38656224', 'river', 976, 114),
#  ('SoKo33088224', 'river', 976, 114),
#  ('SoIl32579224', 'river', 976, 114),
#  ('KiRu26676224', 'river', 976, 114),
#  ('KiRu27230224', 'river', 976, 114),
#  ('KiRu29190224', 'river', 976, 114),
#  ('SoMa34058224', 'river', 974, 124),
#  ('SoKo33219224', 'river', 974, 124),
#  ('SoRu37979224', 'river', 974, 124),
#  ('SoRu35923224', 'river', 974, 124),
#  ('AkRu03965224', 'river', 974, 124),
#  ('AkRu03873224', 'river', 974, 124),
#  ('KiAm21994224', 'river', 974, 124),
#  ('AmAs10470224', 'river', 974, 124),
#  ('HaRu18403224', 'river', 974, 124),
#  ('HaRu20520224', 'river', 972, 133),
#  ('SoRu34806224', 'river', 972, 133),
#  ('SoRu37076224', 'river', 972, 133),
#  ('SoRu35947224', 'river', 972, 133),
#  ('SoRu36917224', 'river', 972, 133),
#  ('SoRu36863224', 'river', 972, 133),
#  ('SoRu37694224', 'river', 972, 133),
#  ('AkRu08293224', 'river', 972, 133),
#  ('AkRu07502224', 'river', 972, 133),
#  ('AkRu06569224', 'river', 972, 133),
#  ('AkRu06043224', 'river', 970, 143),
#  ('KiRu30136224', 'river', 970, 143),
#  ('AmRu14920224', 'river', 970, 143),
#  ('AkKi01306224', 'river', 970, 143),
#  ('AkRu02775224', 'river', 970, 143),
#  ('AkRu03884224', 'river', 970, 143),
#  ('SoMa34437224', 'river', 970, 143),
#  ('SoRu34819224', 'river', 970, 143),
#  ('SoRu35690224', 'river', 970, 143),
#  ('SoRu34993224', 'river', 968, 152),
#  ('SoRu36714224', 'river', 968, 152),
#  ('SoRu36309224', 'river', 968, 152),
#  ('SoRu35887224', 'river', 968, 152),
#  ('SoRu35259224', 'river', 968, 152),
#  ('SoRu36662224', 'river', 968, 152),
#  ('AmRu13923224', 'river', 968, 152),
#  ('AmRu14344224', 'river', 968, 152),
#  ('AmRu15534224', 'river', 968, 152),
#  ('KiRu28921224', 'river', 968, 152),
#  ('KiRu28032224', 'river', 968, 152),
#  ('SoMa33905224', 'river', 968, 152),
#  ('SoRu38735224', 'river', 968, 152),
#  ('SoRu39301224', 'river', 968, 152),
#  ('AkRu03867224', 'river', 968, 152),
#  ('AkRu04499224', 'river', 968, 152),
#  ('AkRu03484224', 'river', 966, 168),
#  ('SoMa33938224', 'river', 966, 168),
#  ('KiZu30842224', 'river', 966, 168),
#  ('SoRu35401224', 'river', 966, 168),
#  ('SoRu34641224', 'river', 966, 168),
#  ('SoRu37575224', 'river', 966, 168),
#  ('SoRu37565224', 'river', 966, 168),
#  ('HaRu20417224', 'river', 966, 168),
#  ('HaSe21171224', 'river', 966, 168),
#  ('AkRu05010224', 'river', 966, 168),
#  ('AkRu04737224', 'river', 966, 168),
#  ('KiRu29093224', 'river', 966, 168),
#  ('KiRu27121224', 'river', 964, 180),
#  ('KiRu27016224', 'river', 964, 180),
#  ('SoRu36192224', 'river', 964, 180),
#  ('SoRu36421224', 'river', 964, 180),
#  ('SoRu36024224', 'river', 964, 180),
#  ('SoCh31958224', 'river', 964, 180),
#  ('AmRu13395224', 'river', 964, 180),
#  ('SoRu39543224', 'river', 964, 180),
#  ('SoRu39559224', 'river', 964, 180),
#  ('KiRu25474224', 'river', 964, 180),
#  ('KiRu25969224', 'river', 962, 190),
#  ('SoBa31833224', 'river', 962, 190),
#  ('SoMa33955224', 'river', 962, 190),
#  ('SoRu36127224', 'river', 962, 190),
#  ('SoRu34778224', 'river', 962, 190),
#  ('HaRu18363224', 'river', 962, 190),
#  ('HaRu18166224', 'river', 962, 190),
#  ('SoRu39048224', 'river', 962, 190),
#  ('SoRu39053224', 'river', 962, 190),
#  ('SoRu38872224', 'river', 960, 199),
#  ('SoRu38793224', 'river', 960, 199),
#  ('SoRu38741224', 'river', 960, 199),
#  ('SoRu38171224', 'river', 960, 199),
#  ('SoRu36744224', 'river', 960, 199),
#  ('SoRu35123224', 'river', 960, 199),
#  ('SoRu37793224', 'river', 960, 199),
#  ('SoRu35252224', 'river', 960, 199),
#  ('SoRu35674224', 'river', 960, 199),
#  ('KiRu29545224', 'river', 960, 199),
#  ('KiRu28764224', 'river', 960, 199),
#  ('KiRu28830224', 'river', 960, 199),
#  ('AkRu05980224', 'river', 960, 199),
#  ('KiAm22276224', 'river', 960, 199),
#  ('AkRu04929224', 'river', 958, 213),
#  ('AkRu07605224', 'river', 958, 213),
#  ('SoRu37476224', 'river', 958, 213),
#  ('SoRu35763224', 'river', 958, 213),
#  ('AkRu03365224', 'river', 958, 213),
#  ('AkRu03403224', 'river', 958, 213),
#  ('AkRu03132224', 'river', 958, 213),
#  ('SoRu38969224', 'river', 958, 213),
#  ('KiRu27963224', 'river', 958, 213),
#  ('KiRu28327224', 'river', 958, 213),
#  ('KiRu30186224', 'river', 958, 213),
#  ('SoKo33076224', 'river', 958, 213),
#  ('SoMa34008224', 'river', 958, 213),
#  ('SoIl32277224', 'river', 958, 213),
#  ('KiZu31151224', 'river', 958, 213),
#  ('HaRu19484224', 'river', 958, 213),
#  ('HaRu17008224', 'river', 958, 213),
#  ('AmRu14867224', 'river', 956, 230),
#  ('SoRu37530224', 'river', 956, 230),
#  ('KiRu25989224', 'river', 956, 230),
#  ('KiIs23590224', 'river', 956, 230),
#  ('SoRu38689224', 'river', 956, 230),
#  ('SoRu39348224', 'river', 956, 230),
#  ('HaRu18188224', 'river', 956, 230),
#  ('HaRu19763224', 'river', 956, 230),
#  ('AmBe11324224', 'river', 956, 230),
#  ('KiZu30986224', 'river', 956, 230),
#  ('SoMa33875224', 'river', 954, 240),
#  ('KiAm22312224', 'river', 954, 240),
#  ('KiRu25825224', 'river', 954, 240),
#  ('HaRu17476224', 'river', 954, 240),
#  ('AkRu05004224', 'river', 954, 240),
#  ('AkRu07488224', 'river', 954, 240),
#  ('SoRu36807224', 'river', 954, 240),
#  ('SoRu37960224', 'river', 954, 240),
#  ('SoRu37137224', 'river', 954, 240),
#  ('SoRu37546224', 'river', 954, 240),
#  ('SoRu35068224', 'river', 954, 240),
#  ('AkRu04281224', 'river', 954, 240),
#  ('AkRu03287224', 'river', 954, 240),
#  ('SoRu39094224', 'river', 954, 240),
#  ('SoRu35096224', 'river', 952, 254),
#  ('SoRu37795224', 'river', 952, 254),
#  ('SoRu37242224', 'river', 952, 254),
#  ('SoMa34520224', 'river', 952, 254),
#  ('KiAm22502224', 'river', 952, 254),
#  ('KiAm22472224', 'river', 952, 254),
#  ('KiRu28805224', 'river', 952, 254),
#  ('SoCh31994224', 'river', 952, 254),
#  ('KiZu31324224', 'river', 952, 254),
#  ('KiRu30435224', 'river', 952, 254),
#  ('SoBa31765224', 'river', 952, 254),
#  ('AkRu06715224', 'river', 952, 254),
#  ('AkRu05485224', 'river', 952, 254),
#  ('AmDa12224224', 'river', 952, 254),
#  ('AmAm09821224', 'river', 952, 254),
#  ('AmAs10765224', 'river', 952, 254),
#  ('HaSe20986224', 'river', 952, 254),
#  ('HaRu20496224', 'river', 950, 271),
#  ('SoBa31800224', 'river', 950, 271),
#  ('SoIl32444224', 'river', 950, 271),
#  ('SoMa34229224', 'river', 950, 271),
#  ('KiRu25832224', 'river', 950, 271),
#  ('KiRu25513224', 'river', 950, 271),
#  ('SoRu39487224', 'river', 950, 271),
#  ('SoRu37117224', 'river', 950, 271),
#  ('AkLu02608224', 'river', 950, 271),
#  ('AkRu04985224', 'river', 950, 271),
#  ('SoRu38653224', 'river', 948, 281),
#  ('SoRu38291224', 'river', 948, 281),
#  ('KiMr24509224', 'river', 948, 281),
#  ('SoCh32058224', 'river', 948, 281),
#  ('AkLu02008224', 'river', 948, 281),
#  ('AkRu08840224', 'river', 948, 281),
#  ('SoRu36867224', 'river', 948, 281),
#  ('SoRu36375224', 'river', 948, 281),
#  ('SoRu38244224', 'river', 948, 281),
#  ('SoRu37744224', 'river', 948, 281),
#  ('SoRu37781224', 'river', 948, 281),
#  ('SoRu37774224', 'river', 948, 281),
#  ('SoRu35221224', 'river', 946, 293),
#  ('KiRu25476224', 'river', 946, 293),
#  ('SoRu38718224', 'river', 946, 293),
#  ('SoRu38896224', 'river', 946, 293),
#  ('AkRu06277224', 'river', 946, 293),
#  ('KiRu27360224', 'river', 946, 293),
#  ('KiRu28687224', 'river', 946, 293),
#  ('AkRu08505224', 'river', 946, 293),
#  ('AmDa11888224', 'river', 946, 293),
#  ('SoKo33438224', 'river', 946, 293),
#  ('SoMa33881224', 'river', 946, 293),
#  ('SoIl32281224', 'river', 946, 293),
#  ('KiZu30680224', 'river', 946, 293),
#  ('SoBa31500224', 'river', 944, 306),
#  ('SoMa34420224', 'river', 944, 306),
#  ('SoKo33308224', 'river', 944, 306),
#  ('AkRu08455224', 'river', 944, 306),
#  ('HaRu18905224', 'river', 944, 306),
#  ('HaRu19701224', 'river', 944, 306),
#  ('SoMa34576224', 'river', 944, 306),
#  ('SoRu36747224', 'river', 944, 306),
#  ('SoRu39588224', 'river', 944, 306),
#  ('HaDj16833224', 'river', 944, 306),
#  ('AmDa11621224', 'river', 944, 306),
#  ('AmRu12872224', 'river', 944, 306),
#  ('AmPw12520224', 'river', 944, 306),
#  ('KiRu28794224', 'river', 944, 306),
#  ('AkRu04137224', 'river', 944, 306),
#  ('SoRu39607224', 'river', 942, 321),
#  ('KiAm22373224', 'river', 942, 321),
#  ('SoKo33556224', 'river', 942, 321),
#  ('SoRu34961224', 'river', 942, 321),
#  ('KiRu29809224', 'river', 942, 321),
#  ('KiRu28147224', 'river', 942, 321),
#  ('KiRu28720224', 'river', 940, 327),
#  ('KiRu29436224', 'river', 940, 327),
#  ('SoMa34180224', 'river', 940, 327),
#  ('KiZu30829224', 'river', 940, 327),
#  ('SoCh32265224', 'river', 940, 327),
#  ('SoRu39540224', 'river', 940, 327),
#  ('SoRu38976224', 'river', 940, 327),
#  ('AkRu07788224', 'river', 940, 327),
#  ('KiIs23736224', 'river', 940, 327),
#  ('KiIs24122224', 'river', 940, 327),
#  ('HaRu19001224', 'river', 940, 327),
#  ('SoMa34439224', 'river', 940, 327),
#  ('SoRu37174224', 'river', 940, 327),
#  ('SoRu34716224', 'river', 940, 327),
#  ('SoRu35266224', 'river', 940, 327),
#  ('AkRu08877224', 'river', 940, 327),
#  ('SoBa31636224', 'river', 938, 343),
#  ('KiRu28789224', 'river', 938, 343),
#  ('SoRu38270224', 'river', 938, 343),
#  ('SoRu37010224', 'river', 938, 343),
#  ('SoRu36423224', 'river', 938, 343),
#  ('AmRu15440224', 'river', 938, 343),
#  ('HaRu19448224', 'river', 938, 343),
#  ('AmAm09481224', 'river', 936, 350),
#  ('SoKo33230224', 'river', 936, 350),
#  ('AkRu06075224', 'river', 936, 350),
#  ('AkRu05182224', 'river', 936, 350),
#  ('SoRu39389224', 'river', 936, 350),
#  ('SoMa34494224', 'river', 936, 350),
#  ('SoRu36805224', 'river', 936, 350),
#  ('SoRu37362224', 'river', 936, 350),
#  ('SoRu36403224', 'river', 934, 358),
#  ('SoRu37286224', 'river', 934, 358),
#  ('KiZu31008224', 'river', 934, 358),
#  ('SoBa31806224', 'river', 934, 358),
#  ('KiRu27555224', 'river', 934, 358),
#  ('KiRu29801224', 'river', 934, 358),
#  ('KiIs23486224', 'river', 934, 358),
#  ('HaRu19170224', 'river', 934, 358),
#  ('KiIs23965224', 'river', 932, 366),
#  ('KiRu30162224', 'river', 932, 366),
#  ('SoKo33077224', 'river', 932, 366),
#  ('SoRu35148224', 'river', 932, 366),
#  ('SoRu37421224', 'river', 932, 366),
#  ('SoRu34742224', 'river', 932, 366),
#  ('SoRu36384224', 'river', 932, 366),
#  ('KiRu29036224', 'river', 932, 366),
#  ('KiRu27525224', 'river', 932, 366),
#  ('KiRu27566224', 'river', 932, 366),
#  ('KiRu27225224', 'river', 932, 366),
#  ('AmAs10202224', 'river', 932, 366),
#  ('AmAs10741224', 'river', 932, 366),
#  ('SoRu38603224', 'river', 932, 366),
#  ('SoRu39133224', 'river', 932, 366),
#  ('AkRu07891224', 'river', 932, 366),
#  ('KiRu25683224', 'river', 930, 382),
#  ('AkRu03096224', 'river', 930, 382),
#  ('SoRu38206224', 'river', 930, 382),
#  ('SoRu35548224', 'river', 930, 382),
#  ('SoKo33262224', 'river', 930, 382),
#  ('KiRu30654224', 'river', 930, 382),
#  ('SoRu39106224', 'river', 930, 382),
#  ('SoRu38802224', 'river', 930, 382),
#  ('SoRu39535224', 'river', 930, 382),
#  ('AmAm09438224', 'river', 930, 382),
#  ('SoRu37358224', 'river', 928, 392),
#  ('SoRu36836224', 'river', 928, 392),
#  ('SoRu37056224', 'river', 928, 392),
#  ('AkRu06100224', 'river', 928, 392),
#  ('HaRu20314224', 'river', 928, 392),
#  ('HaRu17912224', 'river', 928, 392),
#  ('KiRu27288224', 'river', 928, 392),
#  ('SoRu38255224', 'river', 892, 591),
#  ('SoRu36700224', 'river', 892, 591),
#  ('AkRu07175224', 'river', 892, 591),
#  ('SoKo33525224', 'river', 892, 591),
#  ('KiMr25166224', 'river', 890, 602),
#  ('AmAb09163224', 'river', 890, 602),
#  ('AkRu08717224', 'river', 890, 602),
#  ('AmDa12048224', 'river', 890, 602),
#  ('AkRu04398224', 'river', 890, 602),
#  ('SoRu38384224', 'river', 890, 602),
#  ('SoRu38621224', 'river', 890, 602),
#  ('SoRu36100224', 'river', 890, 602),
#  ('SoRu35696224', 'river', 890, 602),
#  ('SoRu34804224', 'river', 890, 602),
#  ('SoRu36826224', 'river', 890, 602),
#  ('SoRu37197224', 'river', 890, 602),
#  ('SoRu37492224', 'river', 888, 614),
#  ('SoRu35014224', 'river', 888, 614),
#  ('SoRu34718224', 'river', 888, 614),
#  ('KiZu31106224', 'river', 888, 614),
#  ('KiRu27945224', 'river', 888, 614),
#  ('KiMr24852224', 'river', 888, 614),
#  ('KiHa22639224', 'river', 888, 614),
#  ('KiIs23715224', 'river', 888, 614),
#  ('AmRu14264224', 'river', 888, 614),
#  ('SoRu38993224', 'river', 888, 614),
#  ('AkRu06953224', 'river', 888, 614),
#  ('AkRu06345224', 'river', 886, 625),
#  ('SoRu36778224', 'river', 886, 625),
#  ('SoRu34820224', 'river', 886, 625),
#  ('SoRu34890224', 'river', 886, 625),
#  ('SoRu37373224', 'river', 886, 625),
#  ('AmAm09465224', 'river', 886, 625),
#  ('AmBe11013224', 'river', 886, 625),
#  ('KiRu29213224', 'river', 886, 625),
#  ('KiRu28679224', 'river', 886, 625),
#  ('SoMa34365224', 'river', 886, 625),
#  ('KiZu30760224', 'river', 886, 625),
#  ('SoMa33642224', 'river', 886, 625),
#  ('AkRu04058224', 'river', 886, 625),
#  ('AkRu04250224', 'river', 884, 638),
#  ('AkRu04572224', 'river', 884, 638),
#  ('SoRu34721224', 'river', 884, 638),
#  ('SoRu37060224', 'river', 884, 638),
#  ('SoRu36251224', 'river', 884, 638),
#  ('KiZu30797224', 'river', 884, 638),
#  ('SoIl32581224', 'river', 884, 638),
#  ('SoIl32518224', 'river', 884, 638),
#  ('SoRu39434224', 'river', 884, 638),
#  ('SoRu38256224', 'river', 884, 638),
#  ('SoRu38675224', 'river', 884, 638),
#  ('SoRu39149224', 'river', 882, 649),
#  ('SoRu38651224', 'river', 882, 649),
#  ('SoRu38466224', 'river', 882, 649),
#  ('SoRu38669224', 'river', 882, 649),
#  ('KiRu28379224', 'river', 882, 649),
#  ('KiAm22135224', 'river', 882, 649),
#  ('AkRu03710224', 'river', 882, 649),
#  ('SoKo33361224', 'river', 882, 649),
#  ('KiZu30747224', 'river', 882, 649),
#  ('SoCh32177224', 'river', 882, 649),
#  ('SoRu36219224', 'river', 882, 649),
#  ('SoRu34736224', 'river', 882, 649),
#  ('SoRu34765224', 'river', 882, 649),
#  ('SoRu36404224', 'river', 880, 662),
#  ('SoRu36810224', 'river', 880, 662),
#  ('SoRu38132224', 'river', 868, 721),
#  ('SoRu35186224', 'river', 868, 721),
#  ('SoIl32695224', 'river', 868, 721),
#  ('SoBa31481224', 'river', 868, 721),
#  ('KiRu30512224', 'river', 868, 721),
#  ('SoCh32151224', 'river', 868, 721),
#  ('SoMa33921224', 'river', 866, 736),
#  ('SoBa31508224', 'river', 866, 736),
#  ('SoBa31881224', 'river', 866, 736),
#  ('SoBa31795224', 'river', 866, 736),
#  ('AkRu03794224', 'river', 866, 736),
#  ('KiRu29505224', 'river', 866, 736),
#  ('KiRu26714224', 'river', 866, 736),
#  ('AmRu14208224', 'river', 866, 736),
#  ('SoRu39635224', 'river', 866, 736),
#  ('SoRu38471224', 'river', 866, 736),
#  ('HaSe21321224', 'river', 866, 736),
#  ('AkRu06810224', 'river', 866, 736),
#  ('SoRu37462224', 'river', 866, 736),
#  ('SoRu36396224', 'river', 866, 736),
#  ('SoRu38057224', 'river', 866, 736),
#  ('KiRu26179224', 'river', 866, 736),
#  ('KiMr24501224', 'river', 866, 736),
#  ('KiRu25925224', 'river', 866, 736),
#  ('KiRu25500224', 'river', 866, 736),
#  ('HaRu18006224', 'river', 864, 755),
#  ('SoRu39090224', 'river', 864, 755),
#  ('SoRu37009224', 'river', 864, 755),
#  ('SoRu36775224', 'river', 864, 755),
#  ('SoRu38062224', 'river', 864, 755),
#  ('SoRu37782224', 'river', 864, 755),
#  ('SoRu37716224', 'river', 864, 755),
#  ('SoRu36570224', 'river', 864, 755),
#  ('SoRu35069224', 'river', 862, 763),
#  ('SoRu37989224', 'river', 862, 763),
#  ('SoRu37144224', 'river', 862, 763),
#  ('KiRu29315224', 'river', 862, 763),
#  ('SoKo33318224', 'river', 862, 763),
#  ('SoRu38848224', 'river', 862, 763),
#  ('AkRu08264224', 'river', 862, 763),
#  ('KiRu27834224', 'river', 860, 770),
#  ('SoRu36336224', 'river', 860, 770),
#  ('SoRu36351224', 'river', 860, 770),
#  ('AkRu03530224', 'river', 860, 770),
#  ('AmRu15302224', 'river', 860, 770),
#  ('SoRu39164224', 'river', 860, 770),
#  ('SoRu39004224', 'river', 860, 770),
#  ('SoRu39110224', 'river', 860, 770),
#  ('AkRu08891224', 'river', 860, 770),
#  ('AmAs10344224', 'river', 858, 779),
#  ('KiRu28753224', 'river', 858, 779),
#  ('AkRu04770224', 'river', 858, 779),
#  ('SoRu35562224', 'river', 858, 779),
#  ('SoRu36314224', 'river', 858, 779),
#  ('SoRu37066224', 'river', 858, 779),
#  ('KiHa22794224', 'river', 858, 779),
#  ('SoRu38533224', 'river', 858, 779),
#  ('KiZu30944224', 'river', 858, 779),
#  ('SoKo33290224', 'river', 856, 788),
#  ('KiZu31029224', 'river', 856, 788),
#  ('SoRu37067224', 'river', 856, 788),
#  ('SoRu37878224', 'river', 856, 788),
#  ('SoRu35587224', 'river', 856, 788),
#  ('SoRu37827224', 'river', 856, 788),
#  ('AkRu03972224', 'river', 856, 788),
#  ('KiRu29163224', 'river', 856, 788),
#  ('SoRu38562224', 'river', 856, 788),
#  ('SoRu39084224', 'river', 854, 797),
#  ('SoMa33687224', 'river', 854, 797),
#  ('SoRu37562224', 'river', 854, 797),
#  ('AkRu08321224', 'river', 854, 797),
#  ('AkRu08169224', 'river', 854, 797),
#  ('KiRu26723224', 'river', 854, 797),
#  ('KiRu25546224', 'river', 854, 797),
#  ('KiMr24916224', 'river', 852, 804),
#  ('SoRu35635224', 'river', 852, 804),
#  ('SoRu36053224', 'river', 852, 804),
#  ('SoRu37297224', 'river', 852, 804),
#  ('SoRu35956224', 'river', 852, 804),
#  ('AkRu02700224', 'river', 852, 804),
#  ('SoBa31462224', 'river', 852, 804),
#  ('SoMa33823224', 'river', 852, 804),
#  ('KiRu28846224', 'river', 852, 804),
#  ('KiRu29946224', 'river', 852, 804),
#  ('AkRu04800224', 'river', 852, 804),
#  ('KiAm22597224', 'river', 850, 815),
#  ('SoRu36876224', 'river', 850, 815),
#  ('SoRu37502224', 'river', 850, 815),
#  ('SoRu38943224', 'river', 850, 815),
#  ('SoRu39335224', 'river', 850, 815),
#  ('SoIl32352224', 'river', 850, 815),
#  ('SoIl32463224', 'river', 848, 821),
#  ('KiZu31216224', 'river', 848, 821),
#  ('SoCh32050224', 'river', 848, 821),
#  ('SoRu37812224', 'river', 848, 821),
#  ('SoRu36299224', 'river', 848, 821),
#  ('SoRu35801224', 'river', 848, 821),
#  ('SoRu37040224', 'river', 848, 821),
#  ('HaRu17777224', 'river', 848, 821),
#  ('AmAm09963224', 'river', 848, 821),
#  ('AmAb09091224', 'river', 848, 821),
#  ('KiRu26016224', 'river', 848, 821),
#  ('AkRu05652224', 'river', 848, 821),
#  ('AkRu05278224', 'river', 848, 821),
#  ('SoRu38490224', 'river', 848, 821),
#  ('KiRu27224224', 'river', 848, 821),
#  ('KiRu29254224', 'river', 848, 821),
#  ('SoRu38200224', 'river', 846, 837),
#  ('SoRu35539224', 'river', 846, 837),
#  ('SoRu36745224', 'river', 846, 837),
#  ('AkRu03750224', 'river', 846, 837),
#  ('SoMa34389224', 'river', 846, 837),
#  ('KiZu31159224', 'river', 846, 837),
#  ('HaRu19268224', 'river', 846, 837),
#  ('HaRu19269224', 'river', 846, 837),
#  ('HaRu17896224', 'river', 846, 837),
#  ('AmRu13976224', 'river', 846, 837),
#  ('AkRu05546224', 'river', 846, 837),
#  ('SoRu34837224', 'river', 844, 848),
#  ('SoRu36585224', 'river', 844, 848),
#  ('SoRu35290224', 'river', 844, 848),
#  ('SoRu35753224', 'river', 844, 848),
#  ('KiRu25385224', 'river', 844, 848),
#  ('KiRu29007224', 'river', 844, 848),
#  ('AmRu14770224', 'river', 844, 848),
#  ('SoRu39104224', 'river', 844, 848),
#  ('SoRu38580224', 'river', 844, 848),
#  ('SoRu38666224', 'river', 842, 857),
#  ('KiMr24805224', 'river', 842, 857),
#  ('SoRu35905224', 'river', 842, 857),
#  ('SoRu35370224', 'river', 842, 857),
#  ('SoRu34960224', 'river', 842, 857),
#  ('SoRu38246224', 'river', 842, 857),
#  ('SoRu37260224', 'river', 842, 857),
#  ('SoRu34674224', 'river', 842, 857),
#  ('SoMa34023224', 'river', 842, 857),
#  ('AkHa00502224', 'river', 842, 857),
#  ('SoIl32862224', 'river', 840, 867),
#  ('SoIl32887224', 'river', 840, 867),
#  ('SoMa34315224', 'river', 840, 867),
#  ('KiRu25665224', 'river', 840, 867),
#  ('SoRu38494224', 'river', 840, 867),
#  ('SoRu39575224', 'river', 840, 867),
#  ('AkRu07650224', 'river', 840, 867),
#  ('SoRu38212224', 'river', 840, 867),
#  ('SoRu34892224', 'river', 840, 867),
#  ('SoRu37830224', 'river', 840, 867),
#  ('AkRu08741224', 'river', 840, 867),
#  ('AmRu13516224', 'river', 840, 867),
#  ('KiRu28692224', 'river', 840, 867),
#  ('KiRu29868224', 'river', 838, 880),
#  ('KiRu28561224', 'river', 838, 880),
#  ('KiRu29450224', 'river', 838, 880),
#  ('KiRu26973224', 'river', 838, 880),
#  ('KiRu28860224', 'river', 838, 880),
#  ('KiRu27885224', 'river', 838, 880),
#  ('KiRu29990224', 'river', 838, 880),
#  ('SoRu35217224', 'river', 838, 880),
#  ('SoRu35227224', 'river', 838, 880),
#  ('SoRu37245224', 'river', 838, 880),
#  ('SoRu35195224', 'river', 838, 880),
#  ('KiIs24193224', 'river', 838, 880),
#  ('KiRu26123224', 'river', 838, 880),
#  ('SoIl32280224', 'river', 838, 880),
#  ('SoIl32646224', 'river', 838, 880),
#  ('SoRu39601224', 'river', 838, 880),
#  ('SoRu38547224', 'river', 838, 880),
#  ('SoRu38523224', 'river', 836, 897),
#  ('SoIl32460224', 'river', 836, 897),
#  ('SoRu38070224', 'river', 836, 897),
#  ('AkLu01601224', 'river', 836, 897),
#  ('KiRu27810224', 'river', 836, 897),
#  ('KiRu27350224', 'river', 836, 897),
#  ('KiRu25305224', 'river', 836, 897),
#  ('KiHa23195224', 'river', 836, 897),
#  ('HaRu17144224', 'river', 836, 897),
#  ('SoRu35747224', 'river', 834, 906),
#  ('SoRu35609224', 'river', 834, 906),
#  ('SoRu38084224', 'river', 834, 906),
#  ('SoRu36054224', 'river', 834, 906),
#  ('SoRu34671224', 'river', 834, 906),
#  ('SoRu38724224', 'river', 834, 906),
#  ('SoRu38430224', 'river', 834, 906),
#  ('SoMa33989224', 'river', 834, 906),
#  ('AkRu04433224', 'river', 834, 906),
#  ('AkRu03975224', 'river', 834, 906),
#  ('AkRu06077224', 'river', 834, 906),
#  ('AmAm09691224', 'river', 834, 906),
#  ('AmAb08991224', 'river', 832, 918),
#  ('AmAm09569224', 'river', 832, 918),
#  ('SoMa34449224', 'river', 832, 918),
#  ('SoRu35258224', 'river', 832, 918),
#  ('SoRu37087224', 'river', 832, 918),
#  ('SoMa34565224', 'river', 832, 918),
#  ('KiRu27380224', 'river', 832, 918),
#  ('KiRu26531224', 'river', 832, 918),
#  ('AmRu13697224', 'river', 832, 918),
#  ('SoCh31946224', 'river', 832, 918),
#  ('SoBa31541224', 'river', 832, 918),
#  ('SoIl32593224', 'river', 832, 918),
#  ('SoRu38589224', 'river', 832, 918),
#  ('AkRu07825224', 'river', 832, 918),
#  ('KiAm22134224', 'river', 832, 918),
#  ('HaYa21433224', 'river', 832, 918),
#  ('HaRu19317224', 'river', 832, 918),
#  ('SoKo33129224', 'river', 830, 935),
#  ('KiRu30151224', 'river', 830, 935),
#  ('SoIl33007224', 'river', 830, 935),
#  ('SoRu37238224', 'river', 830, 935),
#  ('SoRu35409224', 'river', 830, 935),
#  ('SoRu36557224', 'river', 830, 935),
#  ('SoRu35707224', 'river', 830, 935),
#  ('AkLu01766224', 'river', 830, 935),
#  ('HaDj16888224', 'river', 830, 935),
#  ('KiRu27312224', 'river', 830, 935),
#  ('AkRu04664224', 'river', 830, 935),
#  ('AkRu06478224', 'river', 830, 935),
#  ('AkRu07835224', 'river', 830, 935),
#  ('AkRu05910224', 'river', 830, 935),
#  ('AkRu08002224', 'river', 828, 949),
#  ('AmRu13943224', 'river', 828, 949),
#  ('SoKo33526224', 'river', 828, 949),
#  ('KiZu30843224', 'river', 828, 949),
#  ('SoMa33819224', 'river', 828, 949),
#  ('HaRu18627224', 'river', 828, 949),
#  ('HaRu20121224', 'river', 828, 949),
#  ('HaRu18722224', 'river', 828, 949),
#  ('AkKi00923224', 'river', 828, 949),
#  ('AkRu04472224', 'river', 828, 949),
#  ('AkRu04236224', 'river', 828, 949),
#  ('KiRu29978224', 'river', 828, 949),
#  ('KiRu29147224', 'river', 828, 949),
#  ('KiIs24055224', 'river', 828, 949),
#  ('KiHa23014224', 'river', 828, 949),
#  ('HaRu18671224', 'river', 826, 964),
#  ('AkRu05674224', 'river', 826, 964),
#  ('AmAm09746224', 'river', 826, 964),
#  ('AmAs10451224', 'river', 826, 964),
#  ('KiRu30357224', 'river', 826, 964),
#  ('SoMa33627224', 'river', 826, 964),
#  ('KiZu30840224', 'river', 826, 964),
#  ('SoRu38180224', 'river', 826, 964),
#  ('SoRu37522224', 'river', 826, 964),
#  ('SoRu34817224', 'river', 826, 964),
#  ('SoRu34929224', 'river', 826, 964),
#  ('SoRu36031224', 'river', 826, 964),
#  ('SoRu37460224', 'river', 824, 976),
#  ('SoRu37730224', 'river', 824, 976),
#  ('SoRu36663224', 'river', 824, 976),
#  ('SoRu35908224', 'river', 824, 976),
#  ('SoMa34076224', 'river', 824, 976),
#  ('HaRu19506224', 'river', 824, 976),
#  ('HaRu18255224', 'river', 824, 976),
#  ('KiHa23071224', 'river', 824, 976),
#  ('AmDa11995224', 'river', 824, 976),
#  ('AkRu06184224', 'river', 824, 976),
#  ('SoRu38661224', 'river', 824, 976),
#  ('AkRu03802224', 'river', 824, 976),
#  ('AkRu04220224', 'river', 822, 988),
#  ('SoKo33301224', 'river', 822, 988),
#  ('AmRu15887224', 'river', 822, 988),
#  ('SoRu34750224', 'river', 822, 988),
#  ('SoRu35875224', 'river', 822, 988),
#  ('SoRu37715224', 'river', 822, 988),
#  ('KiMr24384224', 'river', 822, 988),
#  ('KiRu25741224', 'river', 822, 988),
#  ('HaRu19852224', 'river', 822, 988),
#  ('SoRu39282224', 'river', 822, 988),
#  ('AkRu07775224', 'river', 822, 988),
#  ('AkRu06125224', 'river', 822, 988),
#  ('AkRu07885224', 'river', 822, 988),
#  ...]

# %%
# %%sql
# SELECT
#     source_id,
#     type_of_water_source,
#     number_of_people_served,
#     DENSE_RANK() OVER(
#         PARTITION BY type_of_water_source ORDER BY number_of_people_served DESC) as priority_rank
# FROM water_source
# WHERE type_of_water_source NOT IN ('tap_in_home')
# LIMIT 3385;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3385 rows affected.
# [('SoRu34798224', 'river', 998, 1),
#  ('SoRu35837224', 'river', 998, 1),
#  ('SoRu36238224', 'river', 998, 1),
#  ('SoRu36791224', 'river', 998, 1),
#  ('SoRu36880224', 'river', 998, 1),
#  ('SoRu38142224', 'river', 998, 1),
#  ('SoRu37756224', 'river', 998, 1),
#  ('SoMa33775224', 'river', 998, 1),
#  ('KiRu30353224', 'river', 998, 1),
#  ('SoIl32972224', 'river', 998, 1),
#  ('KiZu31236224', 'river', 998, 1),
#  ('KiRu28591224', 'river', 998, 1),
#  ('KiMr25030224', 'river', 998, 1),
#  ('KiRu25603224', 'river', 996, 2),
#  ('KiRu26027224', 'river', 996, 2),
#  ('KiRu30532224', 'river', 996, 2),
#  ('SoRu36229224', 'river', 996, 2),
#  ('AkRu08053224', 'river', 996, 2),
#  ('AmAb09070224', 'river', 996, 2),
#  ('SoKo33179224', 'river', 994, 3),
#  ('HaRu20469224', 'river', 994, 3),
#  ('KiRu28404224', 'river', 994, 3),
#  ('KiRu27661224', 'river', 994, 3),
#  ('SoRu36506224', 'river', 994, 3),
#  ('SoRu37912224', 'river', 994, 3),
#  ('SoRu35192224', 'river', 992, 4),
#  ('SoRu36076224', 'river', 992, 4),
#  ('SoRu37032224', 'river', 992, 4),
#  ('SoMa33620224', 'river', 992, 4),
#  ('AkRu04142224', 'river', 992, 4),
#  ('SoRu38498224', 'river', 992, 4),
#  ('SoRu39029224', 'river', 992, 4),
#  ('AmRu13795224', 'river', 992, 4),
#  ('KiRu28002224', 'river', 992, 4),
#  ('KiRu27266224', 'river', 992, 4),
#  ('KiRu29844224', 'river', 992, 4),
#  ('SoRu37904224', 'river', 990, 5),
#  ('SoRu37158224', 'river', 990, 5),
#  ('SoRu37004224', 'river', 990, 5),
#  ('KiRu25651224', 'river', 990, 5),
#  ('SoIl32652224', 'river', 990, 5),
#  ('HaRu17065224', 'river', 990, 5),
#  ('AkRu08333224', 'river', 990, 5),
#  ('AkRu05337224', 'river', 988, 6),
#  ('AkRu06935224', 'river', 988, 6),
#  ('KiAm22552224', 'river', 988, 6),
#  ('KiRu28398224', 'river', 988, 6),
#  ('KiRu28604224', 'river', 988, 6),
#  ('AmAs10139224', 'river', 988, 6),
#  ('AmDa11775224', 'river', 988, 6),
#  ('SoRu37223224', 'river', 988, 6),
#  ('SoRu36894224', 'river', 988, 6),
#  ('SoKo33302224', 'river', 988, 6),
#  ('SoMa34112224', 'river', 988, 6),
#  ('SoKo33275224', 'river', 988, 6),
#  ('SoCh32068224', 'river', 988, 6),
#  ('HaRu20007224', 'river', 988, 6),
#  ('HaRu19708224', 'river', 986, 7),
#  ('KiMr24403224', 'river', 986, 7),
#  ('KiHa23332224', 'river', 986, 7),
#  ('AkRu03607224', 'river', 986, 7),
#  ('KiZu30757224', 'river', 986, 7),
#  ('SoBa31824224', 'river', 986, 7),
#  ('SoMa33961224', 'river', 986, 7),
#  ('SoBa31788224', 'river', 986, 7),
#  ('SoRu36044224', 'river', 986, 7),
#  ('SoRu37968224', 'river', 986, 7),
#  ('SoRu35464224', 'river', 986, 7),
#  ('SoRu36871224', 'river', 986, 7),
#  ('SoRu35151224', 'river', 986, 7),
#  ('SoRu38054224', 'river', 984, 8),
#  ('SoRu37388224', 'river', 984, 8),
#  ('SoRu35074224', 'river', 984, 8),
#  ('KiMr24365224', 'river', 984, 8),
#  ('AmAm09565224', 'river', 984, 8),
#  ('SoRu39564224', 'river', 984, 8),
#  ('SoRu39120224', 'river', 984, 8),
#  ('SoRu38884224', 'river', 984, 8),
#  ('HaRu20269224', 'river', 984, 8),
#  ('SoKo33516224', 'river', 984, 8),
#  ('SoKo33278224', 'river', 984, 8),
#  ('AmRu13767224', 'river', 984, 8),
#  ('AmRu13651224', 'river', 982, 9),
#  ('SoRu38692224', 'river', 982, 9),
#  ('SoRu39206224', 'river', 982, 9),
#  ('AkRu07053224', 'river', 982, 9),
#  ('SoRu36666224', 'river', 982, 9),
#  ('SoRu36065224', 'river', 982, 9),
#  ('SoRu38006224', 'river', 982, 9),
#  ('SoRu37046224', 'river', 982, 9),
#  ('AmBe11055224', 'river', 982, 9),
#  ('AmDa11856224', 'river', 982, 9),
#  ('SoBa31517224', 'river', 982, 9),
#  ('HaRu19782224', 'river', 982, 9),
#  ('HaYa21524224', 'river', 982, 9),
#  ('SoRu34875224', 'river', 980, 10),
#  ('SoRu36036224', 'river', 980, 10),
#  ('KiAm22020224', 'river', 980, 10),
#  ('AmRu13667224', 'river', 980, 10),
#  ('AkRu06243224', 'river', 980, 10),
#  ('AkRu08369224', 'river', 980, 10),
#  ('AkRu06666224', 'river', 980, 10),
#  ('SoBa31654224', 'river', 980, 10),
#  ('SoCh32266224', 'river', 978, 11),
#  ('SoKo33083224', 'river', 978, 11),
#  ('AmRu13901224', 'river', 978, 11),
#  ('SoRu37536224', 'river', 978, 11),
#  ('SoRu37761224', 'river', 978, 11),
#  ('SoRu36311224', 'river', 978, 11),
#  ('SoRu37881224', 'river', 978, 11),
#  ('HaSe21297224', 'river', 978, 11),
#  ('AkRu07584224', 'river', 978, 11),
#  ('AkLu02389224', 'river', 978, 11),
#  ('SoRu35432224', 'river', 976, 12),
#  ('SoRu35138224', 'river', 976, 12),
#  ('SoRu34768224', 'river', 976, 12),
#  ('SoRu38330224', 'river', 976, 12),
#  ('SoRu38656224', 'river', 976, 12),
#  ('SoKo33088224', 'river', 976, 12),
#  ('SoIl32579224', 'river', 976, 12),
#  ('KiRu26676224', 'river', 976, 12),
#  ('KiRu27230224', 'river', 976, 12),
#  ('KiRu29190224', 'river', 976, 12),
#  ('SoMa34058224', 'river', 974, 13),
#  ('SoKo33219224', 'river', 974, 13),
#  ('SoRu37979224', 'river', 974, 13),
#  ('SoRu35923224', 'river', 974, 13),
#  ('AkRu03965224', 'river', 974, 13),
#  ('AkRu03873224', 'river', 974, 13),
#  ('KiAm21994224', 'river', 974, 13),
#  ('AmAs10470224', 'river', 974, 13),
#  ('HaRu18403224', 'river', 974, 13),
#  ('HaRu20520224', 'river', 972, 14),
#  ('SoRu34806224', 'river', 972, 14),
#  ('SoRu37076224', 'river', 972, 14),
#  ('SoRu35947224', 'river', 972, 14),
#  ('SoRu36917224', 'river', 972, 14),
#  ('SoRu36863224', 'river', 972, 14),
#  ('SoRu37694224', 'river', 972, 14),
#  ('AkRu08293224', 'river', 972, 14),
#  ('AkRu07502224', 'river', 972, 14),
#  ('AkRu06569224', 'river', 972, 14),
#  ('AkRu06043224', 'river', 970, 15),
#  ('KiRu30136224', 'river', 970, 15),
#  ('AmRu14920224', 'river', 970, 15),
#  ('AkKi01306224', 'river', 970, 15),
#  ('AkRu02775224', 'river', 970, 15),
#  ('AkRu03884224', 'river', 970, 15),
#  ('SoMa34437224', 'river', 970, 15),
#  ('SoRu34819224', 'river', 970, 15),
#  ('SoRu35690224', 'river', 970, 15),
#  ('SoRu34993224', 'river', 968, 16),
#  ('SoRu36714224', 'river', 968, 16),
#  ('SoRu36309224', 'river', 968, 16),
#  ('SoRu35887224', 'river', 968, 16),
#  ('SoRu35259224', 'river', 968, 16),
#  ('SoRu36662224', 'river', 968, 16),
#  ('AmRu13923224', 'river', 968, 16),
#  ('AmRu14344224', 'river', 968, 16),
#  ('AmRu15534224', 'river', 968, 16),
#  ('KiRu28921224', 'river', 968, 16),
#  ('KiRu28032224', 'river', 968, 16),
#  ('SoMa33905224', 'river', 968, 16),
#  ('SoRu38735224', 'river', 968, 16),
#  ('SoRu39301224', 'river', 968, 16),
#  ('AkRu03867224', 'river', 968, 16),
#  ('AkRu04499224', 'river', 968, 16),
#  ('AkRu03484224', 'river', 966, 17),
#  ('SoMa33938224', 'river', 966, 17),
#  ('KiZu30842224', 'river', 966, 17),
#  ('SoRu35401224', 'river', 966, 17),
#  ('SoRu34641224', 'river', 966, 17),
#  ('SoRu37575224', 'river', 966, 17),
#  ('SoRu37565224', 'river', 966, 17),
#  ('HaRu20417224', 'river', 966, 17),
#  ('HaSe21171224', 'river', 966, 17),
#  ('AkRu05010224', 'river', 966, 17),
#  ('AkRu04737224', 'river', 966, 17),
#  ('KiRu29093224', 'river', 966, 17),
#  ('KiRu27121224', 'river', 964, 18),
#  ('KiRu27016224', 'river', 964, 18),
#  ('SoRu36192224', 'river', 964, 18),
#  ('SoRu36421224', 'river', 964, 18),
#  ('SoRu36024224', 'river', 964, 18),
#  ('SoCh31958224', 'river', 964, 18),
#  ('AmRu13395224', 'river', 964, 18),
#  ('SoRu39543224', 'river', 964, 18),
#  ('SoRu39559224', 'river', 964, 18),
#  ('KiRu25474224', 'river', 964, 18),
#  ('KiRu25969224', 'river', 962, 19),
#  ('SoBa31833224', 'river', 962, 19),
#  ('SoMa33955224', 'river', 962, 19),
#  ('SoRu36127224', 'river', 962, 19),
#  ('SoRu34778224', 'river', 962, 19),
#  ('HaRu18363224', 'river', 962, 19),
#  ('HaRu18166224', 'river', 962, 19),
#  ('SoRu39048224', 'river', 962, 19),
#  ('SoRu39053224', 'river', 962, 19),
#  ('SoRu38872224', 'river', 960, 20),
#  ('SoRu38793224', 'river', 960, 20),
#  ('SoRu38741224', 'river', 960, 20),
#  ('SoRu38171224', 'river', 960, 20),
#  ('SoRu36744224', 'river', 960, 20),
#  ('SoRu35123224', 'river', 960, 20),
#  ('SoRu37793224', 'river', 960, 20),
#  ('SoRu35252224', 'river', 960, 20),
#  ('SoRu35674224', 'river', 960, 20),
#  ('KiRu29545224', 'river', 960, 20),
#  ('KiRu28764224', 'river', 960, 20),
#  ('KiRu28830224', 'river', 960, 20),
#  ('AkRu05980224', 'river', 960, 20),
#  ('KiAm22276224', 'river', 960, 20),
#  ('AkRu04929224', 'river', 958, 21),
#  ('AkRu07605224', 'river', 958, 21),
#  ('SoRu37476224', 'river', 958, 21),
#  ('SoRu35763224', 'river', 958, 21),
#  ('AkRu03365224', 'river', 958, 21),
#  ('AkRu03403224', 'river', 958, 21),
#  ('AkRu03132224', 'river', 958, 21),
#  ('SoRu38969224', 'river', 958, 21),
#  ('KiRu27963224', 'river', 958, 21),
#  ('KiRu28327224', 'river', 958, 21),
#  ('KiRu30186224', 'river', 958, 21),
#  ('SoKo33076224', 'river', 958, 21),
#  ('SoMa34008224', 'river', 958, 21),
#  ('SoIl32277224', 'river', 958, 21),
#  ('KiZu31151224', 'river', 958, 21),
#  ('HaRu19484224', 'river', 958, 21),
#  ('HaRu17008224', 'river', 958, 21),
#  ('AmRu14867224', 'river', 956, 22),
#  ('SoRu37530224', 'river', 956, 22),
#  ('KiRu25989224', 'river', 956, 22),
#  ('KiIs23590224', 'river', 956, 22),
#  ('SoRu38689224', 'river', 956, 22),
#  ('SoRu39348224', 'river', 956, 22),
#  ('HaRu18188224', 'river', 956, 22),
#  ('HaRu19763224', 'river', 956, 22),
#  ('AmBe11324224', 'river', 956, 22),
#  ('KiZu30986224', 'river', 956, 22),
#  ('SoMa33875224', 'river', 954, 23),
#  ('KiAm22312224', 'river', 954, 23),
#  ('KiRu25825224', 'river', 954, 23),
#  ('HaRu17476224', 'river', 954, 23),
#  ('AkRu05004224', 'river', 954, 23),
#  ('AkRu07488224', 'river', 954, 23),
#  ('SoRu36807224', 'river', 954, 23),
#  ('SoRu37960224', 'river', 954, 23),
#  ('SoRu37137224', 'river', 954, 23),
#  ('SoRu37546224', 'river', 954, 23),
#  ('SoRu35068224', 'river', 954, 23),
#  ('AkRu04281224', 'river', 954, 23),
#  ('AkRu03287224', 'river', 954, 23),
#  ('SoRu39094224', 'river', 954, 23),
#  ('SoRu35096224', 'river', 952, 24),
#  ('SoRu37795224', 'river', 952, 24),
#  ('SoRu37242224', 'river', 952, 24),
#  ('SoMa34520224', 'river', 952, 24),
#  ('KiAm22502224', 'river', 952, 24),
#  ('KiAm22472224', 'river', 952, 24),
#  ('KiRu28805224', 'river', 952, 24),
#  ('SoCh31994224', 'river', 952, 24),
#  ('KiZu31324224', 'river', 952, 24),
#  ('KiRu30435224', 'river', 952, 24),
#  ('SoBa31765224', 'river', 952, 24),
#  ('AkRu06715224', 'river', 952, 24),
#  ('AkRu05485224', 'river', 952, 24),
#  ('AmDa12224224', 'river', 952, 24),
#  ('AmAm09821224', 'river', 952, 24),
#  ('AmAs10765224', 'river', 952, 24),
#  ('HaSe20986224', 'river', 952, 24),
#  ('HaRu20496224', 'river', 950, 25),
#  ('SoBa31800224', 'river', 950, 25),
#  ('SoIl32444224', 'river', 950, 25),
#  ('SoMa34229224', 'river', 950, 25),
#  ('KiRu25832224', 'river', 950, 25),
#  ('KiRu25513224', 'river', 950, 25),
#  ('SoRu39487224', 'river', 950, 25),
#  ('SoRu37117224', 'river', 950, 25),
#  ('AkLu02608224', 'river', 950, 25),
#  ('AkRu04985224', 'river', 950, 25),
#  ('SoRu38653224', 'river', 948, 26),
#  ('SoRu38291224', 'river', 948, 26),
#  ('KiMr24509224', 'river', 948, 26),
#  ('SoCh32058224', 'river', 948, 26),
#  ('AkLu02008224', 'river', 948, 26),
#  ('AkRu08840224', 'river', 948, 26),
#  ('SoRu36867224', 'river', 948, 26),
#  ('SoRu36375224', 'river', 948, 26),
#  ('SoRu38244224', 'river', 948, 26),
#  ('SoRu37744224', 'river', 948, 26),
#  ('SoRu37781224', 'river', 948, 26),
#  ('SoRu37774224', 'river', 948, 26),
#  ('SoRu35221224', 'river', 946, 27),
#  ('KiRu25476224', 'river', 946, 27),
#  ('SoRu38718224', 'river', 946, 27),
#  ('SoRu38896224', 'river', 946, 27),
#  ('AkRu06277224', 'river', 946, 27),
#  ('KiRu27360224', 'river', 946, 27),
#  ('KiRu28687224', 'river', 946, 27),
#  ('AkRu08505224', 'river', 946, 27),
#  ('AmDa11888224', 'river', 946, 27),
#  ('SoKo33438224', 'river', 946, 27),
#  ('SoMa33881224', 'river', 946, 27),
#  ('SoIl32281224', 'river', 946, 27),
#  ('KiZu30680224', 'river', 946, 27),
#  ('SoBa31500224', 'river', 944, 28),
#  ('SoMa34420224', 'river', 944, 28),
#  ('SoKo33308224', 'river', 944, 28),
#  ('AkRu08455224', 'river', 944, 28),
#  ('HaRu18905224', 'river', 944, 28),
#  ('HaRu19701224', 'river', 944, 28),
#  ('SoMa34576224', 'river', 944, 28),
#  ('SoRu36747224', 'river', 944, 28),
#  ('SoRu39588224', 'river', 944, 28),
#  ('HaDj16833224', 'river', 944, 28),
#  ('AmDa11621224', 'river', 944, 28),
#  ('AmRu12872224', 'river', 944, 28),
#  ('AmPw12520224', 'river', 944, 28),
#  ('KiRu28794224', 'river', 944, 28),
#  ('AkRu04137224', 'river', 944, 28),
#  ('SoRu39607224', 'river', 942, 29),
#  ('KiAm22373224', 'river', 942, 29),
#  ('SoKo33556224', 'river', 942, 29),
#  ('SoRu34961224', 'river', 942, 29),
#  ('KiRu29809224', 'river', 942, 29),
#  ('KiRu28147224', 'river', 942, 29),
#  ('KiRu28720224', 'river', 940, 30),
#  ('KiRu29436224', 'river', 940, 30),
#  ('SoMa34180224', 'river', 940, 30),
#  ('KiZu30829224', 'river', 940, 30),
#  ('SoCh32265224', 'river', 940, 30),
#  ('SoRu39540224', 'river', 940, 30),
#  ('SoRu38976224', 'river', 940, 30),
#  ('AkRu07788224', 'river', 940, 30),
#  ('KiIs23736224', 'river', 940, 30),
#  ('KiIs24122224', 'river', 940, 30),
#  ('HaRu19001224', 'river', 940, 30),
#  ('SoMa34439224', 'river', 940, 30),
#  ('SoRu37174224', 'river', 940, 30),
#  ('SoRu34716224', 'river', 940, 30),
#  ('SoRu35266224', 'river', 940, 30),
#  ('AkRu08877224', 'river', 940, 30),
#  ('SoBa31636224', 'river', 938, 31),
#  ('KiRu28789224', 'river', 938, 31),
#  ('SoRu38270224', 'river', 938, 31),
#  ('SoRu37010224', 'river', 938, 31),
#  ('SoRu36423224', 'river', 938, 31),
#  ('AmRu15440224', 'river', 938, 31),
#  ('HaRu19448224', 'river', 938, 31),
#  ('AmAm09481224', 'river', 936, 32),
#  ('SoKo33230224', 'river', 936, 32),
#  ('AkRu06075224', 'river', 936, 32),
#  ('AkRu05182224', 'river', 936, 32),
#  ('SoRu39389224', 'river', 936, 32),
#  ('SoMa34494224', 'river', 936, 32),
#  ('SoRu36805224', 'river', 936, 32),
#  ('SoRu37362224', 'river', 936, 32),
#  ('SoRu36403224', 'river', 934, 33),
#  ('SoRu37286224', 'river', 934, 33),
#  ('KiZu31008224', 'river', 934, 33),
#  ('SoBa31806224', 'river', 934, 33),
#  ('KiRu27555224', 'river', 934, 33),
#  ('KiRu29801224', 'river', 934, 33),
#  ('KiIs23486224', 'river', 934, 33),
#  ('HaRu19170224', 'river', 934, 33),
#  ('KiIs23965224', 'river', 932, 34),
#  ('KiRu30162224', 'river', 932, 34),
#  ('SoKo33077224', 'river', 932, 34),
#  ('SoRu35148224', 'river', 932, 34),
#  ('SoRu37421224', 'river', 932, 34),
#  ('SoRu34742224', 'river', 932, 34),
#  ('SoRu36384224', 'river', 932, 34),
#  ('KiRu29036224', 'river', 932, 34),
#  ('KiRu27525224', 'river', 932, 34),
#  ('KiRu27566224', 'river', 932, 34),
#  ('KiRu27225224', 'river', 932, 34),
#  ('AmAs10202224', 'river', 932, 34),
#  ('AmAs10741224', 'river', 932, 34),
#  ('SoRu38603224', 'river', 932, 34),
#  ('SoRu39133224', 'river', 932, 34),
#  ('AkRu07891224', 'river', 932, 34),
#  ('KiRu25683224', 'river', 930, 35),
#  ('AkRu03096224', 'river', 930, 35),
#  ('SoRu38206224', 'river', 930, 35),
#  ('SoRu35548224', 'river', 930, 35),
#  ('SoKo33262224', 'river', 930, 35),
#  ('KiRu30654224', 'river', 930, 35),
#  ('SoRu39106224', 'river', 930, 35),
#  ('SoRu38802224', 'river', 930, 35),
#  ('SoRu39535224', 'river', 930, 35),
#  ('AmAm09438224', 'river', 930, 35),
#  ('SoRu37358224', 'river', 928, 36),
#  ('SoRu36836224', 'river', 928, 36),
#  ('SoRu37056224', 'river', 928, 36),
#  ('AkRu06100224', 'river', 928, 36),
#  ('HaRu20314224', 'river', 928, 36),
#  ('HaRu17912224', 'river', 928, 36),
#  ('KiRu27288224', 'river', 928, 36),
#  ('KiRu27971224', 'river', 928, 36),
#  ('AkRu04085224', 'river', 928, 36),
#  ('SoRu39407224', 'river', 928, 36),
#  ('SoRu38678224', 'river', 928, 36),
#  ('AmRu13793224', 'river', 928, 36),
#  ('SoKo33475224', 'river', 928, 36),
#  ('SoMa34378224', 'river', 928, 36),
#  ('SoCh32201224', 'river', 926, 37),
#  ('SoIl32431224', 'river', 926, 37),
#  ('KiRu30154224', 'river', 926, 37),
#  ('KiRu26560224', 'river', 926, 37),
#  ('AmAs10308224', 'river', 926, 37),
#  ('SoRu35637224', 'river', 926, 37),
#  ('SoRu37884224', 'river', 926, 37),
#  ('SoRu36166224', 'river', 926, 37),
#  ('SoRu34918224', 'river', 926, 37),
#  ('SoRu37687224', 'river', 926, 37),
#  ('AkLu02460224', 'river', 926, 37),
#  ('AkRu02865224', 'river', 924, 38),
#  ('KiRu29918224', 'river', 924, 38),
#  ('AkRu07200224', 'river', 924, 38),
#  ('KiZu31012224', 'river', 924, 38),
#  ('KiZu30955224', 'river', 924, 38),
#  ('SoKo33314224', 'river', 924, 38),
#  ('SoRu37903224', 'river', 924, 38),
#  ('SoRu37549224', 'river', 924, 38),
#  ('KiRu29599224', 'river', 922, 39),
#  ('AkRu02987224', 'river', 922, 39),
#  ('AkRu03500224', 'river', 922, 39),
#  ('SoIl32806224', 'river', 922, 39),
#  ('AmRu13633224', 'river', 922, 39),
#  ('AmRu14055224', 'river', 922, 39),
#  ('SoRu38377224', 'river', 922, 39),
#  ('SoRu39637224', 'river', 920, 40),
#  ('SoRu38789224', 'river', 920, 40),
#  ('KiRu26860224', 'river', 920, 40),
#  ('SoRu36223224', 'river', 920, 40),
#  ('SoRu35326224', 'river', 920, 40),
#  ('SoRu35602224', 'river', 920, 40),
#  ('SoRu37932224', 'river', 920, 40),
#  ('SoRu36465224', 'river', 920, 40),
#  ('SoRu38159224', 'river', 920, 40),
#  ('HaRu20556224', 'river', 920, 40),
#  ('KiRu26174224', 'river', 920, 40),
#  ('KiMr24827224', 'river', 920, 40),
#  ('SoBa31825224', 'river', 920, 40),
#  ('SoMa34258224', 'river', 918, 41),
#  ('SoIl32554224', 'river', 918, 41),
#  ('SoMa33930224', 'river', 918, 41),
#  ('SoKo33116224', 'river', 918, 41),
#  ('SoRu35748224', 'river', 918, 41),
#  ('SoRu37075224', 'river', 918, 41),
#  ('KiRu26217224', 'river', 918, 41),
#  ('KiRu28563224', 'river', 918, 41),
#  ('KiAm22618224', 'river', 918, 41),
#  ('AkHa00232224', 'river', 918, 41),
#  ('AkRu04147224', 'river', 918, 41),
#  ('SoRu37149224', 'river', 916, 42),
#  ('SoRu34766224', 'river', 916, 42),
#  ('SoRu36273224', 'river', 916, 42),
#  ('AmPw12326224', 'river', 916, 42),
#  ('AkRu05389224', 'river', 916, 42),
#  ('AkRu07339224', 'river', 916, 42),
#  ('AkRu07041224', 'river', 916, 42),
#  ('SoBa31897224', 'river', 916, 42),
#  ('KiZu31274224', 'river', 916, 42),
#  ('SoKo33315224', 'river', 914, 43),
#  ('SoRu35623224', 'river', 914, 43),
#  ('SoRu39194224', 'river', 914, 43),
#  ('AkRu04233224', 'river', 914, 43),
#  ('AmAs10630224', 'river', 914, 43),
#  ('HaRu20360224', 'river', 914, 43),
#  ('HaRu19185224', 'river', 914, 43),
#  ('HaRu19566224', 'river', 912, 44),
#  ('AmAm09523224', 'river', 912, 44),
#  ('AmBe10951224', 'river', 912, 44),
#  ('SoRu35825224', 'river', 912, 44),
#  ('SoRu35180224', 'river', 912, 44),
#  ('AkRu07680224', 'river', 912, 44),
#  ('SoRu38340224', 'river', 912, 44),
#  ('KiRu27712224', 'river', 912, 44),
#  ('KiRu27728224', 'river', 912, 44),
#  ('HaDe16315224', 'river', 912, 44),
#  ('AmRu14167224', 'river', 910, 45),
#  ('AkRu06673224', 'river', 910, 45),
#  ('AkRu07333224', 'river', 910, 45),
#  ('AkRu07221224', 'river', 910, 45),
#  ('AmAm09603224', 'river', 910, 45),
#  ('HaRu18599224', 'river', 910, 45),
#  ('SoBa31570224', 'river', 910, 45),
#  ('SoRu36445224', 'river', 910, 45),
#  ('SoRu38079224', 'river', 910, 45),
#  ('SoRu35306224', 'river', 910, 45),
#  ('SoRu34962224', 'river', 910, 45),
#  ('SoRu35487224', 'river', 910, 45),
#  ('AkRu04283224', 'river', 910, 45),
#  ('KiRu25964224', 'river', 910, 45),
#  ('SoRu38301224', 'river', 910, 45),
#  ('SoRu36056224', 'river', 908, 46),
#  ('SoRu35764224', 'river', 908, 46),
#  ('SoRu36115224', 'river', 908, 46),
#  ('SoRu37543224', 'river', 908, 46),
#  ('KiRu30424224', 'river', 908, 46),
#  ('HaRu17692224', 'river', 908, 46),
#  ('KiAm21974224', 'river', 908, 46),
#  ('KiRu26712224', 'river', 908, 46),
#  ('KiRu28787224', 'river', 908, 46),
#  ('KiRu26546224', 'river', 908, 46),
#  ('SoMa33799224', 'river', 906, 47),
#  ('KiZu30865224', 'river', 906, 47),
#  ('SoIl32464224', 'river', 906, 47),
#  ('AmAm09393224', 'river', 906, 47),
#  ('AmPw12370224', 'river', 906, 47),
#  ('AmRu15264224', 'river', 906, 47),
#  ('AkRu06501224', 'river', 906, 47),
#  ('SoRu35755224', 'river', 906, 47),
#  ('SoRu36561224', 'river', 906, 47),
#  ('SoRu35471224', 'river', 906, 47),
#  ('SoRu35419224', 'river', 906, 47),
#  ('SoRu36365224', 'river', 906, 47),
#  ('SoRu39040224', 'river', 906, 47),
#  ('KiIs23620224', 'river', 906, 47),
#  ('KiHa23281224', 'river', 906, 47),
#  ('HaSe21113224', 'river', 906, 47),
#  ('SoRu37507224', 'river', 904, 48),
#  ('KiRu26417224', 'river', 904, 48),
#  ('SoIl32883224', 'river', 904, 48),
#  ('SoMa33931224', 'river', 904, 48),
#  ('KiZu31227224', 'river', 904, 48),
#  ('SoRu38356224', 'river', 904, 48),
#  ('SoRu39211224', 'river', 904, 48),
#  ('AkRu04193224', 'river', 904, 48),
#  ('SoRu35961224', 'river', 902, 49),
#  ('HaSe21134224', 'river', 902, 49),
#  ('SoRu38986224', 'river', 902, 49),
#  ('SoRu39113224', 'river', 902, 49),
#  ('SoRu39399224', 'river', 902, 49),
#  ('SoIl32899224', 'river', 902, 49),
#  ('SoCh31937224', 'river', 902, 49),
#  ('SoKo33188224', 'river', 900, 50),
#  ('KiRu30393224', 'river', 900, 50),
#  ('KiZu31148224', 'river', 900, 50),
#  ('SoRu35298224', 'river', 900, 50),
#  ('SoRu38059224', 'river', 900, 50),
#  ('SoRu37334224', 'river', 900, 50),
#  ('SoMa34472224', 'river', 900, 50),
#  ('SoRu38099224', 'river', 900, 50),
#  ('AkRu04427224', 'river', 900, 50),
#  ('AkRu08561224', 'river', 900, 50),
#  ('KiRu29515224', 'river', 900, 50),
#  ('AkRu04879224', 'river', 900, 50),
#  ('SoRu39208224', 'river', 900, 50),
#  ('SoRu38563224', 'river', 900, 50),
#  ('SoRu39504224', 'river', 898, 51),
#  ('KiRu28244224', 'river', 898, 51),
#  ('SoMa34337224', 'river', 898, 51),
#  ('KiRu30606224', 'river', 898, 51),
#  ('KiRu30158224', 'river', 898, 51),
#  ('SoKo33244224', 'river', 898, 51),
#  ('SoCh32239224', 'river', 898, 51),
#  ('SoCh32253224', 'river', 898, 51),
#  ('SoKo33384224', 'river', 898, 51),
#  ('SoRu37302224', 'river', 898, 51),
#  ('SoRu36715224', 'river', 898, 51),
#  ('AmPw12348224', 'river', 898, 51),
#  ('AmAs10890224', 'river', 898, 51),
#  ('HaAm16017224', 'river', 898, 51),
#  ('AmRu15775224', 'river', 898, 51),
#  ('AkRu08404224', 'river', 898, 51),
#  ('KiMr24266224', 'river', 898, 51),
#  ('KiHa23471224', 'river', 896, 52),
#  ('AmAs10555224', 'river', 896, 52),
#  ('KiRu28696224', 'river', 896, 52),
#  ('KiRu28790224', 'river', 896, 52),
#  ('KiRu28098224', 'river', 896, 52),
#  ('SoRu38991224', 'river', 896, 52),
#  ('SoRu39328224', 'river', 896, 52),
#  ('SoRu36693224', 'river', 896, 52),
#  ('SoRu37365224', 'river', 896, 52),
#  ('SoRu37112224', 'river', 896, 52),
#  ('HaRu17551224', 'river', 896, 52),
#  ('KiRu28690224', 'river', 894, 53),
#  ('KiRu26965224', 'river', 894, 53),
#  ('KiZu31119224', 'river', 894, 53),
#  ('SoMa34226224', 'river', 894, 53),
#  ('SoBa31898224', 'river', 894, 53),
#  ('SoBa31543224', 'river', 894, 53),
#  ('SoRu38669224', 'river', 882, 59),
#  ('KiRu28379224', 'river', 882, 59),
#  ('KiAm22135224', 'river', 882, 59),
#  ('AkRu03710224', 'river', 882, 59),
#  ('SoKo33361224', 'river', 882, 59),
#  ('KiZu30747224', 'river', 882, 59),
#  ('SoCh32177224', 'river', 882, 59),
#  ('SoRu36219224', 'river', 882, 59),
#  ('SoRu34736224', 'river', 882, 59),
#  ('SoRu34765224', 'river', 882, 59),
#  ('SoRu36404224', 'river', 880, 60),
#  ('SoRu36810224', 'river', 880, 60),
#  ('SoRu37611224', 'river', 880, 60),
#  ('SoMa34484224', 'river', 880, 60),
#  ('AkRu07304224', 'river', 880, 60),
#  ('AmRu13162224', 'river', 880, 60),
#  ('SoMa34387224', 'river', 880, 60),
#  ('AmRu15009224', 'river', 880, 60),
#  ('KiRu26178224', 'river', 878, 61),
#  ('KiRu25243224', 'river', 878, 61),
#  ('KiIs23771224', 'river', 878, 61),
#  ('KiHa23305224', 'river', 878, 61),
#  ('HaRu19607224', 'river', 878, 61),
#  ('SoRu38873224', 'river', 878, 61),
#  ('SoRu35295224', 'river', 878, 61),
#  ('SoRu37101224', 'river', 878, 61),
#  ('KiRu29429224', 'river', 878, 61),
#  ('SoKo33431224', 'river', 878, 61),
#  ('AkRu03948224', 'river', 878, 61),
#  ('SoRu35680224', 'river', 876, 62),
#  ('SoRu34985224', 'river', 876, 62),
#  ('SoRu35482224', 'river', 876, 62),
#  ('SoRu37304224', 'river', 876, 62),
#  ('AkRu05226224', 'river', 876, 62),
#  ('AmRu15600224', 'river', 876, 62),
#  ('HaDe16442224', 'river', 876, 62),
#  ('SoRu39021224', 'river', 876, 62),
#  ('SoIl32775224', 'river', 876, 62),
#  ('KiZu31102224', 'river', 876, 62),
#  ('SoCh32176224', 'river', 874, 63),
#  ('SoBa31718224', 'river', 874, 63),
#  ('SoMa34305224', 'river', 874, 63),
#  ('SoRu35895224', 'river', 874, 63),
#  ('SoRu37107224', 'river', 874, 63),
#  ('AkRu03324224', 'river', 874, 63),
#  ('AkRu07202224', 'river', 874, 63),
#  ('HaRu17624224', 'river', 874, 63),
#  ('SoRu39296224', 'river', 874, 63),
#  ('SoRu38473224', 'river', 874, 63),
#  ('SoRu38409224', 'river', 874, 63),
#  ('KiRu28737224', 'river', 874, 63),
#  ('KiRu28968224', 'river', 872, 64),
#  ('KiRu30272224', 'river', 872, 64),
#  ('SoIl32770224', 'river', 872, 64),
#  ('AmRu15140224', 'river', 872, 64),
#  ('AmRu13278224', 'river', 872, 64),
#  ('AkLu01758224', 'river', 872, 64),
#  ('SoRu37506224', 'river', 872, 64),
#  ('HaRu20599224', 'river', 872, 64),
#  ('AkRu03860224', 'river', 870, 65),
#  ('KiRu27720224', 'river', 870, 65),
#  ('KiMr24890224', 'river', 870, 65),
#  ('AkRu07106224', 'river', 870, 65),
#  ('AmRu13643224', 'river', 870, 65),
#  ('SoMa33987224', 'river', 870, 65),
#  ('KiRu30041224', 'river', 870, 65),
#  ('SoRu34836224', 'river', 870, 65),
#  ('SoRu35107224', 'river', 870, 65),
#  ('SoRu39437224', 'river', 870, 65),
#  ('SoRu39108224', 'river', 868, 66),
#  ('KiRu28619224', 'river', 868, 66),
#  ('KiRu28841224', 'river', 868, 66),
#  ('KiRu28744224', 'river', 868, 66),
#  ('HaRu20285224', 'river', 868, 66),
#  ('AkRu04107224', 'river', 868, 66),
#  ('AkRu02853224', 'river', 868, 66),
#  ('KiAm22422224', 'river', 868, 66),
#  ('SoRu35194224', 'river', 868, 66),
#  ('SoRu38132224', 'river', 868, 66),
#  ('SoRu35186224', 'river', 868, 66),
#  ('SoIl32695224', 'river', 868, 66),
#  ('SoBa31481224', 'river', 868, 66),
#  ('KiRu30512224', 'river', 868, 66),
#  ('SoCh32151224', 'river', 868, 66),
#  ('SoMa33921224', 'river', 866, 67),
#  ('SoBa31508224', 'river', 866, 67),
#  ('SoBa31881224', 'river', 866, 67),
#  ('SoBa31795224', 'river', 866, 67),
#  ('AkRu03794224', 'river', 866, 67),
#  ('KiRu29505224', 'river', 866, 67),
#  ('KiRu26714224', 'river', 866, 67),
#  ('AmRu14208224', 'river', 866, 67),
#  ('SoRu39635224', 'river', 866, 67),
#  ('SoRu38471224', 'river', 866, 67),
#  ('HaSe21321224', 'river', 866, 67),
#  ('AkRu06810224', 'river', 866, 67),
#  ('SoRu37462224', 'river', 866, 67),
#  ('SoRu36396224', 'river', 866, 67),
#  ('SoRu38057224', 'river', 866, 67),
#  ('KiRu26179224', 'river', 866, 67),
#  ('KiMr24501224', 'river', 866, 67),
#  ('KiRu25925224', 'river', 866, 67),
#  ('KiRu25500224', 'river', 866, 67),
#  ('HaRu18006224', 'river', 864, 68),
#  ('SoRu39090224', 'river', 864, 68),
#  ('SoRu37009224', 'river', 864, 68),
#  ('SoRu36775224', 'river', 864, 68),
#  ('SoRu38062224', 'river', 864, 68),
#  ('SoRu37782224', 'river', 864, 68),
#  ('SoRu37716224', 'river', 864, 68),
#  ('SoRu36570224', 'river', 864, 68),
#  ('SoRu35069224', 'river', 862, 69),
#  ('SoRu37989224', 'river', 862, 69),
#  ('SoRu37144224', 'river', 862, 69),
#  ('KiRu29315224', 'river', 862, 69),
#  ('SoKo33318224', 'river', 862, 69),
#  ('SoRu38848224', 'river', 862, 69),
#  ('AkRu08264224', 'river', 862, 69),
#  ('KiRu27834224', 'river', 860, 70),
#  ('SoRu36336224', 'river', 860, 70),
#  ('SoRu36351224', 'river', 860, 70),
#  ('AkRu03530224', 'river', 860, 70),
#  ('AmRu15302224', 'river', 860, 70),
#  ('SoRu39164224', 'river', 860, 70),
#  ('SoRu39004224', 'river', 860, 70),
#  ('SoRu39110224', 'river', 860, 70),
#  ('AkRu08891224', 'river', 860, 70),
#  ('AmAs10344224', 'river', 858, 71),
#  ('KiRu28753224', 'river', 858, 71),
#  ('AkRu04770224', 'river', 858, 71),
#  ('SoRu35562224', 'river', 858, 71),
#  ('SoRu36314224', 'river', 858, 71),
#  ('SoRu37066224', 'river', 858, 71),
#  ('KiHa22794224', 'river', 858, 71),
#  ('SoRu38533224', 'river', 858, 71),
#  ('KiZu30944224', 'river', 858, 71),
#  ('SoKo33290224', 'river', 856, 72),
#  ('KiZu31029224', 'river', 856, 72),
#  ('SoRu37067224', 'river', 856, 72),
#  ('SoRu37878224', 'river', 856, 72),
#  ('SoRu35587224', 'river', 856, 72),
#  ('SoRu37827224', 'river', 856, 72),
#  ('AkRu03972224', 'river', 856, 72),
#  ('KiRu29163224', 'river', 856, 72),
#  ('SoRu38562224', 'river', 856, 72),
#  ('SoRu39084224', 'river', 854, 73),
#  ('SoMa33687224', 'river', 854, 73),
#  ('SoRu37562224', 'river', 854, 73),
#  ('AkRu08321224', 'river', 854, 73),
#  ('AkRu08169224', 'river', 854, 73),
#  ('KiRu26723224', 'river', 854, 73),
#  ('KiRu25546224', 'river', 854, 73),
#  ('KiMr24916224', 'river', 852, 74),
#  ('SoRu35635224', 'river', 852, 74),
#  ('SoRu36053224', 'river', 852, 74),
#  ('SoRu37297224', 'river', 852, 74),
#  ('SoRu35956224', 'river', 852, 74),
#  ('AkRu02700224', 'river', 852, 74),
#  ('SoBa31462224', 'river', 852, 74),
#  ('SoMa33823224', 'river', 852, 74),
#  ('KiRu28846224', 'river', 852, 74),
#  ('KiRu29946224', 'river', 852, 74),
#  ('AkRu04800224', 'river', 852, 74),
#  ('KiAm22597224', 'river', 850, 75),
#  ('SoRu36876224', 'river', 850, 75),
#  ('SoRu37502224', 'river', 850, 75),
#  ('SoRu38943224', 'river', 850, 75),
#  ('SoRu39335224', 'river', 850, 75),
#  ('SoIl32352224', 'river', 850, 75),
#  ('SoIl32463224', 'river', 848, 76),
#  ('KiZu31216224', 'river', 848, 76),
#  ('SoCh32050224', 'river', 848, 76),
#  ('SoRu37812224', 'river', 848, 76),
#  ('SoRu36299224', 'river', 848, 76),
#  ('SoRu35801224', 'river', 848, 76),
#  ('SoRu37040224', 'river', 848, 76),
#  ('HaRu17777224', 'river', 848, 76),
#  ('AmAm09963224', 'river', 848, 76),
#  ('AmAb09091224', 'river', 848, 76),
#  ('KiRu26016224', 'river', 848, 76),
#  ('AkRu05652224', 'river', 848, 76),
#  ('AkRu05278224', 'river', 848, 76),
#  ('SoRu38490224', 'river', 848, 76),
#  ('KiRu27224224', 'river', 848, 76),
#  ('KiRu29254224', 'river', 848, 76),
#  ('SoRu38200224', 'river', 846, 77),
#  ('SoRu35539224', 'river', 846, 77),
#  ('SoRu36745224', 'river', 846, 77),
#  ('AkRu03750224', 'river', 846, 77),
#  ('SoMa34389224', 'river', 846, 77),
#  ('KiZu31159224', 'river', 846, 77),
#  ('HaRu19268224', 'river', 846, 77),
#  ('HaRu19269224', 'river', 846, 77),
#  ('HaRu17896224', 'river', 846, 77),
#  ('AmRu13976224', 'river', 846, 77),
#  ('AkRu05546224', 'river', 846, 77),
#  ('SoRu34837224', 'river', 844, 78),
#  ('SoRu36585224', 'river', 844, 78),
#  ('SoRu35290224', 'river', 844, 78),
#  ('SoRu35753224', 'river', 844, 78),
#  ('KiRu25385224', 'river', 844, 78),
#  ('KiRu29007224', 'river', 844, 78),
#  ('AmRu14770224', 'river', 844, 78),
#  ('SoRu39104224', 'river', 844, 78),
#  ('SoRu38580224', 'river', 844, 78),
#  ('SoRu38666224', 'river', 842, 79),
#  ('KiMr24805224', 'river', 842, 79),
#  ('SoRu35905224', 'river', 842, 79),
#  ('SoRu35370224', 'river', 842, 79),
#  ('SoRu34960224', 'river', 842, 79),
#  ('SoRu38246224', 'river', 842, 79),
#  ('SoRu37260224', 'river', 842, 79),
#  ('SoRu34674224', 'river', 842, 79),
#  ('SoMa34023224', 'river', 842, 79),
#  ('AkHa00502224', 'river', 842, 79),
#  ('SoIl32862224', 'river', 840, 80),
#  ('SoIl32887224', 'river', 840, 80),
#  ('SoMa34315224', 'river', 840, 80),
#  ('KiRu25665224', 'river', 840, 80),
#  ('SoRu38494224', 'river', 840, 80),
#  ('SoRu39575224', 'river', 840, 80),
#  ('AkRu07650224', 'river', 840, 80),
#  ('SoRu38212224', 'river', 840, 80),
#  ('SoRu34892224', 'river', 840, 80),
#  ('SoRu37830224', 'river', 840, 80),
#  ('AkRu08741224', 'river', 840, 80),
#  ('AmRu13516224', 'river', 840, 80),
#  ('KiRu28692224', 'river', 840, 80),
#  ('KiRu29868224', 'river', 838, 81),
#  ('KiRu28561224', 'river', 838, 81),
#  ('KiRu29450224', 'river', 838, 81),
#  ('KiRu26973224', 'river', 838, 81),
#  ('KiRu28860224', 'river', 838, 81),
#  ('KiRu27885224', 'river', 838, 81),
#  ('KiRu29990224', 'river', 838, 81),
#  ('SoRu35217224', 'river', 838, 81),
#  ('SoRu35227224', 'river', 838, 81),
#  ('SoRu37245224', 'river', 838, 81),
#  ('SoRu35195224', 'river', 838, 81),
#  ('KiIs24193224', 'river', 838, 81),
#  ('KiRu26123224', 'river', 838, 81),
#  ('SoIl32280224', 'river', 838, 81),
#  ('SoIl32646224', 'river', 838, 81),
#  ('SoRu39601224', 'river', 838, 81),
#  ('SoRu38547224', 'river', 838, 81),
#  ('SoRu38523224', 'river', 836, 82),
#  ('SoIl32460224', 'river', 836, 82),
#  ('SoRu38070224', 'river', 836, 82),
#  ('AkLu01601224', 'river', 836, 82),
#  ('KiRu27810224', 'river', 836, 82),
#  ('KiRu27350224', 'river', 836, 82),
#  ('KiRu25305224', 'river', 836, 82),
#  ('KiHa23195224', 'river', 836, 82),
#  ('HaRu17144224', 'river', 836, 82),
#  ('SoRu35747224', 'river', 834, 83),
#  ('SoRu35609224', 'river', 834, 83),
#  ('SoRu38084224', 'river', 834, 83),
#  ('SoRu36054224', 'river', 834, 83),
#  ('SoRu34671224', 'river', 834, 83),
#  ('SoRu38724224', 'river', 834, 83),
#  ('SoRu38430224', 'river', 834, 83),
#  ('SoMa33989224', 'river', 834, 83),
#  ('AkRu04433224', 'river', 834, 83),
#  ('AkRu03975224', 'river', 834, 83),
#  ('AkRu06077224', 'river', 834, 83),
#  ('AmAm09691224', 'river', 834, 83),
#  ('AmAb08991224', 'river', 832, 84),
#  ('AmAm09569224', 'river', 832, 84),
#  ('SoMa34449224', 'river', 832, 84),
#  ('SoRu35258224', 'river', 832, 84),
#  ('SoRu37087224', 'river', 832, 84),
#  ('SoMa34565224', 'river', 832, 84),
#  ('KiRu27380224', 'river', 832, 84),
#  ('KiRu26531224', 'river', 832, 84),
#  ('AmRu13697224', 'river', 832, 84),
#  ('SoCh31946224', 'river', 832, 84),
#  ('SoBa31541224', 'river', 832, 84),
#  ('SoIl32593224', 'river', 832, 84),
#  ('SoRu38589224', 'river', 832, 84),
#  ('AkRu07825224', 'river', 832, 84),
#  ('KiAm22134224', 'river', 832, 84),
#  ('HaYa21433224', 'river', 832, 84),
#  ('HaRu19317224', 'river', 832, 84),
#  ('SoKo33129224', 'river', 830, 85),
#  ('KiRu30151224', 'river', 830, 85),
#  ('SoIl33007224', 'river', 830, 85),
#  ('SoRu37238224', 'river', 830, 85),
#  ('SoRu35409224', 'river', 830, 85),
#  ('SoRu36557224', 'river', 830, 85),
#  ('SoRu35707224', 'river', 830, 85),
#  ('AkLu01766224', 'river', 830, 85),
#  ('HaDj16888224', 'river', 830, 85),
#  ('KiRu27312224', 'river', 830, 85),
#  ('AkRu04664224', 'river', 830, 85),
#  ('AkRu06478224', 'river', 830, 85),
#  ('AkRu07835224', 'river', 830, 85),
#  ('AkRu05910224', 'river', 830, 85),
#  ('AkRu08002224', 'river', 828, 86),
#  ('AmRu13943224', 'river', 828, 86),
#  ('SoKo33526224', 'river', 828, 86),
#  ('KiZu30843224', 'river', 828, 86),
#  ('SoMa33819224', 'river', 828, 86),
#  ('HaRu18627224', 'river', 828, 86),
#  ('HaRu20121224', 'river', 828, 86),
#  ('HaRu18722224', 'river', 828, 86),
#  ('AkKi00923224', 'river', 828, 86),
#  ('AkRu04472224', 'river', 828, 86),
#  ('AkRu04236224', 'river', 828, 86),
#  ('KiRu29978224', 'river', 828, 86),
#  ('KiRu29147224', 'river', 828, 86),
#  ('KiIs24055224', 'river', 828, 86),
#  ('KiHa23014224', 'river', 828, 86),
#  ('HaRu18671224', 'river', 826, 87),
#  ('AkRu05674224', 'river', 826, 87),
#  ('AmAm09746224', 'river', 826, 87),
#  ('AmAs10451224', 'river', 826, 87),
#  ('KiRu30357224', 'river', 826, 87),
#  ('SoMa33627224', 'river', 826, 87),
#  ('KiZu30840224', 'river', 826, 87),
#  ('SoRu38180224', 'river', 826, 87),
#  ('SoRu37522224', 'river', 826, 87),
#  ('SoRu34817224', 'river', 826, 87),
#  ('SoRu34929224', 'river', 826, 87),
#  ('SoRu36031224', 'river', 826, 87),
#  ('SoRu37460224', 'river', 824, 88),
#  ('SoRu37730224', 'river', 824, 88),
#  ('SoRu36663224', 'river', 824, 88),
#  ('SoRu35908224', 'river', 824, 88),
#  ('SoMa34076224', 'river', 824, 88),
#  ('HaRu19506224', 'river', 824, 88),
#  ('HaRu18255224', 'river', 824, 88),
#  ('KiHa23071224', 'river', 824, 88),
#  ('AmDa11995224', 'river', 824, 88),
#  ('AkRu06184224', 'river', 824, 88),
#  ('SoRu38661224', 'river', 824, 88),
#  ('AkRu03802224', 'river', 824, 88),
#  ('AkRu04220224', 'river', 822, 89),
#  ('SoKo33301224', 'river', 822, 89),
#  ('AmRu15887224', 'river', 822, 89),
#  ('SoRu34750224', 'river', 822, 89),
#  ('SoRu35875224', 'river', 822, 89),
#  ('SoRu37715224', 'river', 822, 89),
#  ('KiMr24384224', 'river', 822, 89),
#  ('KiRu25741224', 'river', 822, 89),
#  ('HaRu19852224', 'river', 822, 89),
#  ('SoRu39282224', 'river', 822, 89),
#  ('AkRu07775224', 'river', 822, 89),
#  ('AkRu06125224', 'river', 822, 89),
#  ('AkRu07885224', 'river', 822, 89),
#  ...]

# %%
# %%sql
# SELECT
#     source_id,
#     type_of_water_source,
#     number_of_people_served,
#     ROW_NUMBER() OVER(
#         PARTITION BY type_of_water_source ORDER BY number_of_people_served DESC) as priority_rank
# FROM water_source
# WHERE type_of_water_source NOT IN ('tap_in_home')
# LIMIT 3385;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3385 rows affected.
# [('SoRu34798224', 'river', 998, 1),
#  ('SoRu35837224', 'river', 998, 2),
#  ('SoRu36238224', 'river', 998, 3),
#  ('SoRu36791224', 'river', 998, 4),
#  ('SoRu36880224', 'river', 998, 5),
#  ('SoRu38142224', 'river', 998, 6),
#  ('SoRu37756224', 'river', 998, 7),
#  ('SoMa33775224', 'river', 998, 8),
#  ('KiRu30353224', 'river', 998, 9),
#  ('SoIl32972224', 'river', 998, 10),
#  ('KiZu31236224', 'river', 998, 11),
#  ('KiRu28591224', 'river', 998, 12),
#  ('KiMr25030224', 'river', 998, 13),
#  ('KiRu25603224', 'river', 996, 14),
#  ('KiRu26027224', 'river', 996, 15),
#  ('KiRu30532224', 'river', 996, 16),
#  ('SoRu36229224', 'river', 996, 17),
#  ('AkRu08053224', 'river', 996, 18),
#  ('AmAb09070224', 'river', 996, 19),
#  ('SoKo33179224', 'river', 994, 20),
#  ('HaRu20469224', 'river', 994, 21),
#  ('KiRu28404224', 'river', 994, 22),
#  ('KiRu27661224', 'river', 994, 23),
#  ('SoRu36506224', 'river', 994, 24),
#  ('SoRu37912224', 'river', 994, 25),
#  ('SoRu35192224', 'river', 992, 26),
#  ('SoRu36076224', 'river', 992, 27),
#  ('SoRu37032224', 'river', 992, 28),
#  ('SoMa33620224', 'river', 992, 29),
#  ('AkRu04142224', 'river', 992, 30),
#  ('SoRu38498224', 'river', 992, 31),
#  ('SoRu39029224', 'river', 992, 32),
#  ('AmRu13795224', 'river', 992, 33),
#  ('KiRu28002224', 'river', 992, 34),
#  ('KiRu27266224', 'river', 992, 35),
#  ('KiRu29844224', 'river', 992, 36),
#  ('SoRu37904224', 'river', 990, 37),
#  ('SoRu37158224', 'river', 990, 38),
#  ('SoRu37004224', 'river', 990, 39),
#  ('KiRu25651224', 'river', 990, 40),
#  ('SoIl32652224', 'river', 990, 41),
#  ('HaRu17065224', 'river', 990, 42),
#  ('AkRu08333224', 'river', 990, 43),
#  ('SoRu37881224', 'river', 978, 110),
#  ('HaSe21297224', 'river', 978, 111),
#  ('AkRu07584224', 'river', 978, 112),
#  ('AkLu02389224', 'river', 978, 113),
#  ('SoRu35432224', 'river', 976, 114),
#  ('SoRu35138224', 'river', 976, 115),
#  ('SoRu34768224', 'river', 976, 116),
#  ('SoRu38330224', 'river', 976, 117),
#  ('SoRu38656224', 'river', 976, 118),
#  ('SoKo33088224', 'river', 976, 119),
#  ('SoIl32579224', 'river', 976, 120),
#  ('KiRu26676224', 'river', 976, 121),
#  ('KiRu27230224', 'river', 976, 122),
#  ('KiRu29190224', 'river', 976, 123),
#  ('SoMa34058224', 'river', 974, 124),
#  ('SoKo33219224', 'river', 974, 125),
#  ('SoRu37979224', 'river', 974, 126),
#  ('SoRu35923224', 'river', 974, 127),
#  ('AkRu03965224', 'river', 974, 128),
#  ('AkRu03873224', 'river', 974, 129),
#  ('KiAm21994224', 'river', 974, 130),
#  ('AmAs10470224', 'river', 974, 131),
#  ('HaRu18403224', 'river', 974, 132),
#  ('HaRu20520224', 'river', 972, 133),
#  ('SoRu34806224', 'river', 972, 134),
#  ('SoRu37076224', 'river', 972, 135),
#  ('SoRu35947224', 'river', 972, 136),
#  ('SoRu36917224', 'river', 972, 137),
#  ('SoRu36863224', 'river', 972, 138),
#  ('SoRu37694224', 'river', 972, 139),
#  ('AkRu08293224', 'river', 972, 140),
#  ('AkRu07502224', 'river', 972, 141),
#  ('AkRu06569224', 'river', 972, 142),
#  ('AkRu06043224', 'river', 970, 143),
#  ('KiRu30136224', 'river', 970, 144),
#  ('AmRu14920224', 'river', 970, 145),
#  ('AkKi01306224', 'river', 970, 146),
#  ('AkRu02775224', 'river', 970, 147),
#  ('AkRu03884224', 'river', 970, 148),
#  ('SoMa34437224', 'river', 970, 149),
#  ('SoRu34819224', 'river', 970, 150),
#  ('SoRu35690224', 'river', 970, 151),
#  ('SoRu34993224', 'river', 968, 152),
#  ('SoRu36714224', 'river', 968, 153),
#  ('SoRu36309224', 'river', 968, 154),
#  ('SoRu35887224', 'river', 968, 155),
#  ('SoRu35259224', 'river', 968, 156),
#  ('SoRu36662224', 'river', 968, 157),
#  ('AmRu13923224', 'river', 968, 158),
#  ('AmRu14344224', 'river', 968, 159),
#  ('AmRu15534224', 'river', 968, 160),
#  ('KiRu28921224', 'river', 968, 161),
#  ('KiRu28032224', 'river', 968, 162),
#  ('SoMa33905224', 'river', 968, 163),
#  ('SoRu38735224', 'river', 968, 164),
#  ('SoRu39301224', 'river', 968, 165),
#  ('AkRu03867224', 'river', 968, 166),
#  ('AkRu04499224', 'river', 968, 167),
#  ('AkRu03484224', 'river', 966, 168),
#  ('SoMa33938224', 'river', 966, 169),
#  ('KiZu30842224', 'river', 966, 170),
#  ('SoRu35401224', 'river', 966, 171),
#  ('SoRu34641224', 'river', 966, 172),
#  ('SoRu37575224', 'river', 966, 173),
#  ('SoRu37565224', 'river', 966, 174),
#  ('HaRu20417224', 'river', 966, 175),
#  ('HaSe21171224', 'river', 966, 176),
#  ('AkRu05010224', 'river', 966, 177),
#  ('AkRu04737224', 'river', 966, 178),
#  ('KiRu29093224', 'river', 966, 179),
#  ('KiRu27121224', 'river', 964, 180),
#  ('KiRu27016224', 'river', 964, 181),
#  ('SoRu36192224', 'river', 964, 182),
#  ('SoRu36421224', 'river', 964, 183),
#  ('SoRu36024224', 'river', 964, 184),
#  ('SoCh31958224', 'river', 964, 185),
#  ('AmRu13395224', 'river', 964, 186),
#  ('SoRu39543224', 'river', 964, 187),
#  ('SoRu39559224', 'river', 964, 188),
#  ('KiRu25474224', 'river', 964, 189),
#  ('KiRu25969224', 'river', 962, 190),
#  ('SoBa31833224', 'river', 962, 191),
#  ('SoMa33955224', 'river', 962, 192),
#  ('SoRu36127224', 'river', 962, 193),
#  ('SoRu34778224', 'river', 962, 194),
#  ('HaRu18363224', 'river', 962, 195),
#  ('HaRu18166224', 'river', 962, 196),
#  ('SoRu39048224', 'river', 962, 197),
#  ('SoRu39053224', 'river', 962, 198),
#  ('SoRu38872224', 'river', 960, 199),
#  ('SoRu38793224', 'river', 960, 200),
#  ('SoRu38741224', 'river', 960, 201),
#  ('SoRu38171224', 'river', 960, 202),
#  ('SoRu36744224', 'river', 960, 203),
#  ('SoRu35123224', 'river', 960, 204),
#  ('SoRu37793224', 'river', 960, 205),
#  ('SoRu35252224', 'river', 960, 206),
#  ('SoRu35674224', 'river', 960, 207),
#  ('KiRu29545224', 'river', 960, 208),
#  ('KiRu28764224', 'river', 960, 209),
#  ('KiRu28830224', 'river', 960, 210),
#  ('AkRu05980224', 'river', 960, 211),
#  ('KiAm22276224', 'river', 960, 212),
#  ('AkRu04929224', 'river', 958, 213),
#  ('AkRu07605224', 'river', 958, 214),
#  ('SoRu37476224', 'river', 958, 215),
#  ('SoRu35763224', 'river', 958, 216),
#  ('AkRu03365224', 'river', 958, 217),
#  ('AkRu03403224', 'river', 958, 218),
#  ('AkRu03132224', 'river', 958, 219),
#  ('SoRu38969224', 'river', 958, 220),
#  ('KiRu27963224', 'river', 958, 221),
#  ('KiRu28327224', 'river', 958, 222),
#  ('KiRu30186224', 'river', 958, 223),
#  ('SoKo33076224', 'river', 958, 224),
#  ('SoMa34008224', 'river', 958, 225),
#  ('SoIl32277224', 'river', 958, 226),
#  ('KiZu31151224', 'river', 958, 227),
#  ('HaRu19484224', 'river', 958, 228),
#  ('HaRu17008224', 'river', 958, 229),
#  ('AmRu14867224', 'river', 956, 230),
#  ('SoRu37530224', 'river', 956, 231),
#  ('KiRu25989224', 'river', 956, 232),
#  ('KiIs23590224', 'river', 956, 233),
#  ('SoRu38689224', 'river', 956, 234),
#  ('SoRu39348224', 'river', 956, 235),
#  ('HaRu18188224', 'river', 956, 236),
#  ('HaRu19763224', 'river', 956, 237),
#  ('AmBe11324224', 'river', 956, 238),
#  ('KiZu30986224', 'river', 956, 239),
#  ('SoMa33875224', 'river', 954, 240),
#  ('KiAm22312224', 'river', 954, 241),
#  ('KiRu25825224', 'river', 954, 242),
#  ('AkRu08455224', 'river', 944, 309),
#  ('HaRu18905224', 'river', 944, 310),
#  ('HaRu19701224', 'river', 944, 311),
#  ('SoMa34576224', 'river', 944, 312),
#  ('SoRu36747224', 'river', 944, 313),
#  ('SoRu39588224', 'river', 944, 314),
#  ('HaDj16833224', 'river', 944, 315),
#  ('AmDa11621224', 'river', 944, 316),
#  ('AmRu12872224', 'river', 944, 317),
#  ('AmPw12520224', 'river', 944, 318),
#  ('KiRu28794224', 'river', 944, 319),
#  ('AkRu04137224', 'river', 944, 320),
#  ('SoRu39607224', 'river', 942, 321),
#  ('KiAm22373224', 'river', 942, 322),
#  ('SoKo33556224', 'river', 942, 323),
#  ('SoRu34961224', 'river', 942, 324),
#  ('KiRu29809224', 'river', 942, 325),
#  ('KiRu28147224', 'river', 942, 326),
#  ('KiRu28720224', 'river', 940, 327),
#  ('KiRu29436224', 'river', 940, 328),
#  ('SoMa34180224', 'river', 940, 329),
#  ('KiZu30829224', 'river', 940, 330),
#  ('SoCh32265224', 'river', 940, 331),
#  ('SoRu39540224', 'river', 940, 332),
#  ('SoRu38976224', 'river', 940, 333),
#  ('AkRu07788224', 'river', 940, 334),
#  ('KiIs23736224', 'river', 940, 335),
#  ('KiIs24122224', 'river', 940, 336),
#  ('HaRu19001224', 'river', 940, 337),
#  ('SoMa34439224', 'river', 940, 338),
#  ('SoRu37174224', 'river', 940, 339),
#  ('SoRu34716224', 'river', 940, 340),
#  ('SoRu35266224', 'river', 940, 341),
#  ('AkRu08877224', 'river', 940, 342),
#  ('SoBa31636224', 'river', 938, 343),
#  ('KiRu28789224', 'river', 938, 344),
#  ('SoRu38270224', 'river', 938, 345),
#  ('SoRu37010224', 'river', 938, 346),
#  ('SoRu36423224', 'river', 938, 347),
#  ('AmRu15440224', 'river', 938, 348),
#  ('HaRu19448224', 'river', 938, 349),
#  ('AmAm09481224', 'river', 936, 350),
#  ('SoKo33230224', 'river', 936, 351),
#  ('AkRu06075224', 'river', 936, 352),
#  ('AkRu05182224', 'river', 936, 353),
#  ('SoRu39389224', 'river', 936, 354),
#  ('SoMa34494224', 'river', 936, 355),
#  ('SoRu36805224', 'river', 936, 356),
#  ('SoRu37362224', 'river', 936, 357),
#  ('SoRu36403224', 'river', 934, 358),
#  ('SoRu37286224', 'river', 934, 359),
#  ('KiZu31008224', 'river', 934, 360),
#  ('SoBa31806224', 'river', 934, 361),
#  ('KiRu27555224', 'river', 934, 362),
#  ('KiRu29801224', 'river', 934, 363),
#  ('KiIs23486224', 'river', 934, 364),
#  ('HaRu19170224', 'river', 934, 365),
#  ('KiIs23965224', 'river', 932, 366),
#  ('KiRu30162224', 'river', 932, 367),
#  ('SoKo33077224', 'river', 932, 368),
#  ('SoRu35148224', 'river', 932, 369),
#  ('SoRu37421224', 'river', 932, 370),
#  ('SoRu34742224', 'river', 932, 371),
#  ('SoRu36384224', 'river', 932, 372),
#  ('KiRu29036224', 'river', 932, 373),
#  ('KiRu27525224', 'river', 932, 374),
#  ('KiRu27566224', 'river', 932, 375),
#  ('KiRu27225224', 'river', 932, 376),
#  ('AmAs10202224', 'river', 932, 377),
#  ('AmAs10741224', 'river', 932, 378),
#  ('SoRu38603224', 'river', 932, 379),
#  ('SoRu39133224', 'river', 932, 380),
#  ('AkRu07891224', 'river', 932, 381),
#  ('KiRu25683224', 'river', 930, 382),
#  ('AkRu03096224', 'river', 930, 383),
#  ('SoRu38206224', 'river', 930, 384),
#  ('SoRu35548224', 'river', 930, 385),
#  ('SoKo33262224', 'river', 930, 386),
#  ('KiRu30654224', 'river', 930, 387),
#  ('SoRu39106224', 'river', 930, 388),
#  ('SoRu38802224', 'river', 930, 389),
#  ('SoRu39535224', 'river', 930, 390),
#  ('AmAm09438224', 'river', 930, 391),
#  ('SoRu37358224', 'river', 928, 392),
#  ('SoRu36836224', 'river', 928, 393),
#  ('SoRu37056224', 'river', 928, 394),
#  ('AkRu06100224', 'river', 928, 395),
#  ('HaRu20314224', 'river', 928, 396),
#  ('HaRu17912224', 'river', 928, 397),
#  ('KiRu27288224', 'river', 928, 398),
#  ('KiRu27971224', 'river', 928, 399),
#  ('AkRu04085224', 'river', 928, 400),
#  ('SoRu39407224', 'river', 928, 401),
#  ('SoRu38678224', 'river', 928, 402),
#  ('AmRu13793224', 'river', 928, 403),
#  ('SoKo33475224', 'river', 928, 404),
#  ('SoMa34378224', 'river', 928, 405),
#  ('SoCh32201224', 'river', 926, 406),
#  ('SoIl32431224', 'river', 926, 407),
#  ('KiRu30154224', 'river', 926, 408),
#  ('KiRu26560224', 'river', 926, 409),
#  ('AmAs10308224', 'river', 926, 410),
#  ('SoRu35637224', 'river', 926, 411),
#  ('SoRu37884224', 'river', 926, 412),
#  ('SoRu36166224', 'river', 926, 413),
#  ('SoRu34918224', 'river', 926, 414),
#  ('SoRu37687224', 'river', 926, 415),
#  ('AkLu02460224', 'river', 926, 416),
#  ('AkRu02865224', 'river', 924, 417),
#  ('KiRu29918224', 'river', 924, 418),
#  ('AkRu07200224', 'river', 924, 419),
#  ('KiZu31012224', 'river', 924, 420),
#  ('KiZu30955224', 'river', 924, 421),
#  ('SoKo33314224', 'river', 924, 422),
#  ('SoRu37903224', 'river', 924, 423),
#  ('SoRu37549224', 'river', 924, 424),
#  ('KiRu29599224', 'river', 922, 425),
#  ('AkRu02987224', 'river', 922, 426),
#  ('AkRu03500224', 'river', 922, 427),
#  ('SoIl32806224', 'river', 922, 428),
#  ('AmRu13633224', 'river', 922, 429),
#  ('AmRu14055224', 'river', 922, 430),
#  ('SoRu38377224', 'river', 922, 431),
#  ('SoRu39637224', 'river', 920, 432),
#  ('SoRu38789224', 'river', 920, 433),
#  ('KiRu26860224', 'river', 920, 434),
#  ('SoRu36223224', 'river', 920, 435),
#  ('SoRu35326224', 'river', 920, 436),
#  ('SoRu35602224', 'river', 920, 437),
#  ('SoRu37932224', 'river', 920, 438),
#  ('SoRu36465224', 'river', 920, 439),
#  ('SoRu38159224', 'river', 920, 440),
#  ('HaRu20556224', 'river', 920, 441),
#  ('SoRu37060224', 'river', 884, 641),
#  ('SoRu36251224', 'river', 884, 642),
#  ('KiZu30797224', 'river', 884, 643),
#  ('SoIl32581224', 'river', 884, 644),
#  ('SoIl32518224', 'river', 884, 645),
#  ('SoRu39434224', 'river', 884, 646),
#  ('SoRu38256224', 'river', 884, 647),
#  ('SoRu38675224', 'river', 884, 648),
#  ('SoRu39149224', 'river', 882, 649),
#  ('SoRu38651224', 'river', 882, 650),
#  ('SoRu38466224', 'river', 882, 651),
#  ('SoRu38669224', 'river', 882, 652),
#  ('KiRu28379224', 'river', 882, 653),
#  ('KiAm22135224', 'river', 882, 654),
#  ('AkRu03710224', 'river', 882, 655),
#  ('SoKo33361224', 'river', 882, 656),
#  ('KiZu30747224', 'river', 882, 657),
#  ('SoCh32177224', 'river', 882, 658),
#  ('SoRu36219224', 'river', 882, 659),
#  ('SoRu34736224', 'river', 882, 660),
#  ('SoRu34765224', 'river', 882, 661),
#  ('SoRu36404224', 'river', 880, 662),
#  ('SoRu36810224', 'river', 880, 663),
#  ('SoRu37611224', 'river', 880, 664),
#  ('SoMa34484224', 'river', 880, 665),
#  ('AkRu07304224', 'river', 880, 666),
#  ('AmRu13162224', 'river', 880, 667),
#  ('SoMa34387224', 'river', 880, 668),
#  ('AmRu15009224', 'river', 880, 669),
#  ('KiRu26178224', 'river', 878, 670),
#  ('KiRu25243224', 'river', 878, 671),
#  ('KiIs23771224', 'river', 878, 672),
#  ('KiHa23305224', 'river', 878, 673),
#  ('HaRu19607224', 'river', 878, 674),
#  ('SoRu38873224', 'river', 878, 675),
#  ('SoRu35295224', 'river', 878, 676),
#  ('SoRu37101224', 'river', 878, 677),
#  ('KiRu29429224', 'river', 878, 678),
#  ('SoKo33431224', 'river', 878, 679),
#  ('AkRu03948224', 'river', 878, 680),
#  ('SoRu35680224', 'river', 876, 681),
#  ('SoRu34985224', 'river', 876, 682),
#  ('SoRu35482224', 'river', 876, 683),
#  ('SoRu37304224', 'river', 876, 684),
#  ('AkRu05226224', 'river', 876, 685),
#  ('AmRu15600224', 'river', 876, 686),
#  ('HaDe16442224', 'river', 876, 687),
#  ('SoRu39021224', 'river', 876, 688),
#  ('SoIl32775224', 'river', 876, 689),
#  ('KiZu31102224', 'river', 876, 690),
#  ('SoCh32176224', 'river', 874, 691),
#  ('SoBa31718224', 'river', 874, 692),
#  ('SoMa34305224', 'river', 874, 693),
#  ('SoRu35895224', 'river', 874, 694),
#  ('SoRu37107224', 'river', 874, 695),
#  ('AkRu03324224', 'river', 874, 696),
#  ('AkRu07202224', 'river', 874, 697),
#  ('HaRu17624224', 'river', 874, 698),
#  ('SoRu39296224', 'river', 874, 699),
#  ('SoRu38473224', 'river', 874, 700),
#  ('SoRu38409224', 'river', 874, 701),
#  ('KiRu28737224', 'river', 874, 702),
#  ('KiRu28968224', 'river', 872, 703),
#  ('KiRu30272224', 'river', 872, 704),
#  ('SoIl32770224', 'river', 872, 705),
#  ('AmRu15140224', 'river', 872, 706),
#  ('AkRu03530224', 'river', 860, 773),
#  ('AmRu15302224', 'river', 860, 774),
#  ('SoRu39164224', 'river', 860, 775),
#  ('SoRu39004224', 'river', 860, 776),
#  ('SoRu39110224', 'river', 860, 777),
#  ('AkRu08891224', 'river', 860, 778),
#  ('AmAs10344224', 'river', 858, 779),
#  ('KiRu28753224', 'river', 858, 780),
#  ('AkRu04770224', 'river', 858, 781),
#  ('SoRu35562224', 'river', 858, 782),
#  ('SoRu36314224', 'river', 858, 783),
#  ('SoRu37066224', 'river', 858, 784),
#  ('KiHa22794224', 'river', 858, 785),
#  ('SoRu38533224', 'river', 858, 786),
#  ('KiZu30944224', 'river', 858, 787),
#  ('SoKo33290224', 'river', 856, 788),
#  ('KiZu31029224', 'river', 856, 789),
#  ('SoRu37067224', 'river', 856, 790),
#  ('SoRu37878224', 'river', 856, 791),
#  ('SoRu35587224', 'river', 856, 792),
#  ('SoRu37827224', 'river', 856, 793),
#  ('AkRu03972224', 'river', 856, 794),
#  ('KiRu29163224', 'river', 856, 795),
#  ('SoRu38562224', 'river', 856, 796),
#  ('SoRu39084224', 'river', 854, 797),
#  ('SoMa33687224', 'river', 854, 798),
#  ('SoRu37562224', 'river', 854, 799),
#  ('AkRu08321224', 'river', 854, 800),
#  ('AkRu08169224', 'river', 854, 801),
#  ('KiRu26723224', 'river', 854, 802),
#  ('KiRu25546224', 'river', 854, 803),
#  ('KiMr24916224', 'river', 852, 804),
#  ('SoRu35635224', 'river', 852, 805),
#  ('SoRu36053224', 'river', 852, 806),
#  ('SoRu37297224', 'river', 852, 807),
#  ('SoRu35956224', 'river', 852, 808),
#  ('AkRu02700224', 'river', 852, 809),
#  ('SoBa31462224', 'river', 852, 810),
#  ('SoMa33823224', 'river', 852, 811),
#  ('KiRu28846224', 'river', 852, 812),
#  ('KiRu29946224', 'river', 852, 813),
#  ('AkRu04800224', 'river', 852, 814),
#  ('KiAm22597224', 'river', 850, 815),
#  ('SoRu36876224', 'river', 850, 816),
#  ('SoRu37502224', 'river', 850, 817),
#  ('SoRu38943224', 'river', 850, 818),
#  ('SoRu39335224', 'river', 850, 819),
#  ('SoIl32352224', 'river', 850, 820),
#  ('SoIl32463224', 'river', 848, 821),
#  ('KiZu31216224', 'river', 848, 822),
#  ('SoCh32050224', 'river', 848, 823),
#  ('SoRu37812224', 'river', 848, 824),
#  ('SoRu36299224', 'river', 848, 825),
#  ('SoRu35801224', 'river', 848, 826),
#  ('SoRu37040224', 'river', 848, 827),
#  ('HaRu17777224', 'river', 848, 828),
#  ('AmAm09963224', 'river', 848, 829),
#  ('AmAb09091224', 'river', 848, 830),
#  ('KiRu26016224', 'river', 848, 831),
#  ('AkRu05652224', 'river', 848, 832),
#  ('AkRu05278224', 'river', 848, 833),
#  ('SoRu38490224', 'river', 848, 834),
#  ('KiRu27224224', 'river', 848, 835),
#  ('KiRu29254224', 'river', 848, 836),
#  ('SoRu38200224', 'river', 846, 837),
#  ('SoRu35539224', 'river', 846, 838),
#  ('SoRu36745224', 'river', 846, 839),
#  ('AkRu03750224', 'river', 846, 840),
#  ('SoMa34389224', 'river', 846, 841),
#  ('KiZu31159224', 'river', 846, 842),
#  ('HaRu19268224', 'river', 846, 843),
#  ('HaRu19269224', 'river', 846, 844),
#  ('HaRu17896224', 'river', 846, 845),
#  ('AmRu13976224', 'river', 846, 846),
#  ('AkRu05546224', 'river', 846, 847),
#  ('SoRu34837224', 'river', 844, 848),
#  ('SoRu36585224', 'river', 844, 849),
#  ('SoRu35290224', 'river', 844, 850),
#  ('SoRu35753224', 'river', 844, 851),
#  ('KiRu25385224', 'river', 844, 852),
#  ('KiRu29007224', 'river', 844, 853),
#  ('AmRu14770224', 'river', 844, 854),
#  ('SoRu39104224', 'river', 844, 855),
#  ('SoRu38580224', 'river', 844, 856),
#  ('SoRu38666224', 'river', 842, 857),
#  ('KiMr24805224', 'river', 842, 858),
#  ('SoRu35905224', 'river', 842, 859),
#  ('SoRu35370224', 'river', 842, 860),
#  ('SoRu34960224', 'river', 842, 861),
#  ('SoRu38246224', 'river', 842, 862),
#  ('SoRu37260224', 'river', 842, 863),
#  ('SoRu34674224', 'river', 842, 864),
#  ('SoMa34023224', 'river', 842, 865),
#  ('AkHa00502224', 'river', 842, 866),
#  ('SoIl32862224', 'river', 840, 867),
#  ('SoIl32887224', 'river', 840, 868),
#  ('SoMa34315224', 'river', 840, 869),
#  ('KiRu25665224', 'river', 840, 870),
#  ('SoRu38494224', 'river', 840, 871),
#  ('SoRu39575224', 'river', 840, 872),
#  ('AkRu07650224', 'river', 840, 873),
#  ('SoRu38212224', 'river', 840, 874),
#  ('SoRu34892224', 'river', 840, 875),
#  ('SoRu37830224', 'river', 840, 876),
#  ('AkRu08741224', 'river', 840, 877),
#  ('AmRu13516224', 'river', 840, 878),
#  ('KiRu28692224', 'river', 840, 879),
#  ('KiRu29868224', 'river', 838, 880),
#  ('KiRu28561224', 'river', 838, 881),
#  ('KiRu29450224', 'river', 838, 882),
#  ('KiRu26973224', 'river', 838, 883),
#  ('KiRu28860224', 'river', 838, 884),
#  ('KiRu27885224', 'river', 838, 885),
#  ('KiRu29990224', 'river', 838, 886),
#  ('SoRu35217224', 'river', 838, 887),
#  ('SoRu35227224', 'river', 838, 888),
#  ('SoRu37245224', 'river', 838, 889),
#  ('SoRu35195224', 'river', 838, 890),
#  ('KiIs24193224', 'river', 838, 891),
#  ('KiRu26123224', 'river', 838, 892),
#  ('SoIl32280224', 'river', 838, 893),
#  ('SoIl32646224', 'river', 838, 894),
#  ('SoRu39601224', 'river', 838, 895),
#  ('SoRu38547224', 'river', 838, 896),
#  ('SoRu38523224', 'river', 836, 897),
#  ('SoIl32460224', 'river', 836, 898),
#  ('SoRu38070224', 'river', 836, 899),
#  ('AkLu01601224', 'river', 836, 900),
#  ('KiRu27810224', 'river', 836, 901),
#  ('KiRu27350224', 'river', 836, 902),
#  ('KiRu25305224', 'river', 836, 903),
#  ('KiHa23195224', 'river', 836, 904),
#  ('HaRu17144224', 'river', 836, 905),
#  ('SoRu35747224', 'river', 834, 906),
#  ('SoRu35609224', 'river', 834, 907),
#  ('SoRu38084224', 'river', 834, 908),
#  ('SoRu36054224', 'river', 834, 909),
#  ('SoRu34671224', 'river', 834, 910),
#  ('SoRu38724224', 'river', 834, 911),
#  ('SoRu38430224', 'river', 834, 912),
#  ('SoMa33989224', 'river', 834, 913),
#  ('AkRu04433224', 'river', 834, 914),
#  ('AkRu03975224', 'river', 834, 915),
#  ('AkRu06077224', 'river', 834, 916),
#  ('AmAm09691224', 'river', 834, 917),
#  ('AmAb08991224', 'river', 832, 918),
#  ('AmAm09569224', 'river', 832, 919),
#  ('SoMa34449224', 'river', 832, 920),
#  ('SoRu35258224', 'river', 832, 921),
#  ('SoRu37087224', 'river', 832, 922),
#  ('SoMa34565224', 'river', 832, 923),
#  ('KiRu27380224', 'river', 832, 924),
#  ('KiRu26531224', 'river', 832, 925),
#  ('AmRu13697224', 'river', 832, 926),
#  ('SoCh31946224', 'river', 832, 927),
#  ('SoBa31541224', 'river', 832, 928),
#  ('SoIl32593224', 'river', 832, 929),
#  ('SoRu38589224', 'river', 832, 930),
#  ('AkRu07825224', 'river', 832, 931),
#  ('KiAm22134224', 'river', 832, 932),
#  ('HaYa21433224', 'river', 832, 933),
#  ('HaRu19317224', 'river', 832, 934),
#  ('SoKo33129224', 'river', 830, 935),
#  ('KiRu30151224', 'river', 830, 936),
#  ('SoIl33007224', 'river', 830, 937),
#  ('SoRu37238224', 'river', 830, 938),
#  ('SoRu35409224', 'river', 830, 939),
#  ('SoRu36557224', 'river', 830, 940),
#  ('SoRu35707224', 'river', 830, 941),
#  ('AkLu01766224', 'river', 830, 942),
#  ('HaDj16888224', 'river', 830, 943),
#  ('KiRu27312224', 'river', 830, 944),
#  ('AkRu04664224', 'river', 830, 945),
#  ('AkRu06478224', 'river', 830, 946),
#  ('AkRu07835224', 'river', 830, 947),
#  ('AkRu05910224', 'river', 830, 948),
#  ('AkRu08002224', 'river', 828, 949),
#  ('AmRu13943224', 'river', 828, 950),
#  ('SoKo33526224', 'river', 828, 951),
#  ('KiZu30843224', 'river', 828, 952),
#  ('SoMa33819224', 'river', 828, 953),
#  ('HaRu18627224', 'river', 828, 954),
#  ('HaRu20121224', 'river', 828, 955),
#  ('HaRu18722224', 'river', 828, 956),
#  ('AkKi00923224', 'river', 828, 957),
#  ('AkRu04472224', 'river', 828, 958),
#  ('AkRu04236224', 'river', 828, 959),
#  ('KiRu29978224', 'river', 828, 960),
#  ('KiRu29147224', 'river', 828, 961),
#  ('KiIs24055224', 'river', 828, 962),
#  ('KiHa23014224', 'river', 828, 963),
#  ('HaRu18671224', 'river', 826, 964),
#  ('AkRu05674224', 'river', 826, 965),
#  ('AmAm09746224', 'river', 826, 966),
#  ('AmAs10451224', 'river', 826, 967),
#  ('KiRu30357224', 'river', 826, 968),
#  ('SoMa33627224', 'river', 826, 969),
#  ('KiZu30840224', 'river', 826, 970),
#  ('SoRu38180224', 'river', 826, 971),
#  ('SoRu37522224', 'river', 826, 972),
#  ('SoRu34817224', 'river', 826, 973),
#  ('SoRu34929224', 'river', 826, 974),
#  ('SoRu36031224', 'river', 826, 975),
#  ('SoRu37460224', 'river', 824, 976),
#  ('SoRu37730224', 'river', 824, 977),
#  ('SoRu36663224', 'river', 824, 978),
#  ('SoRu35908224', 'river', 824, 979),
#  ('SoMa34076224', 'river', 824, 980),
#  ('HaRu19506224', 'river', 824, 981),
#  ('HaRu18255224', 'river', 824, 982),
#  ('KiHa23071224', 'river', 824, 983),
#  ('AmDa11995224', 'river', 824, 984),
#  ('AkRu06184224', 'river', 824, 985),
#  ('SoRu38661224', 'river', 824, 986),
#  ('AkRu03802224', 'river', 824, 987),
#  ('AkRu04220224', 'river', 822, 988),
#  ('SoKo33301224', 'river', 822, 989),
#  ('AmRu15887224', 'river', 822, 990),
#  ('SoRu34750224', 'river', 822, 991),
#  ('SoRu35875224', 'river', 822, 992),
#  ('SoRu37715224', 'river', 822, 993),
#  ('KiMr24384224', 'river', 822, 994),
#  ('KiRu25741224', 'river', 822, 995),
#  ('HaRu19852224', 'river', 822, 996),
#  ('SoRu39282224', 'river', 822, 997),
#  ('AkRu07775224', 'river', 822, 998),
#  ('AkRu06125224', 'river', 822, 999),
#  ('AkRu07885224', 'river', 822, 1000),
#  ...]

# %% [markdown]
# ## 6. Analysing queues
# **Uncovering when citizens collect water.**

# %% [markdown]
# ### 6.26. The `visits` Table
# The `visits` table documented all of the visits our field surveyors made to each location. For most sources, one visit was enough, but if there were
# queues, they visited the location a couple of times to get a good idea of the time it took for people to queue for water. So we have the time that
# they collected the data, how many times the site was visited, and how long people had to queue for water.

# %% [markdown]
# These are some of the things I think are worth looking at:
# 1. How long did the survey take?
# 2. What is the average total queue time for water?
# <br>**Hint** *Keep in mind that many sources like taps_in_home have no queues. These
# are just recorded as 0 in the time_in_queue column, so when we calculate averages, we need to exclude those rows. Try using NULLIF() do to
# this*
# 3. What is the average queue time on different days?
# 4. How can we communicate this information efficiently?
# <br>**Hint** *Look at visits, especially the time_of_record column. It is an SQL `DateTime` datatype, so we can use all of the `DateTime` functions to aggregate data for each day and even per hour*

# %%
# %%sql
# SELECT * FROM visits LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14)]

# %%
# %%sql
# #1.How long did the survey take?
# SELECT
#     MAX(time_of_record) as survey_finishing_date,
#     MIN(time_of_record) as survey_starting_date,
#     DATEDIFF(MAX(time_of_record), MIN(time_of_record)) as survey_time_taken
# FROM visits;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 1 rows affected.
# [(datetime.datetime(2023, 7, 14, 13, 53), datetime.datetime(2021, 1, 1, 9, 10), 924)]

# %%
# %%sql
# #2. What is the average total queue time for water?
# SELECT
#     AVG(time_in_queue) as average_queue_time
# FROM visits
# WHERE time_in_queue <> 0;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 1 rows affected.
# [(Decimal('123.2574'),)]

# %%
# %%sql
# # 3.What is the average queue time on different days?
# SELECT
#     DAYNAME(time_of_record) as day_of_week,
#     ROUND(AVG(time_in_queue)) as avg_queue_time
# FROM visits
# GROUP BY DAYNAME(time_of_record);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 7 rows affected.
# [('Friday', Decimal('53')),
#  ('Saturday', Decimal('246')),
#  ('Sunday', Decimal('82')),
#  ('Monday', Decimal('60')),
#  ('Tuesday', Decimal('47')),
#  ('Wednesday', Decimal('43')),
#  ('Thursday', Decimal('46'))]

# %%
# %%sql
# # 4.How can we communicate this information efficiently?
# SELECT
#     HOUR(time_of_record) as hour_of_day,
#     ROUND(AVG(time_in_queue)) as avg_queue_time
# FROM visits
# GROUP BY HOUR(time_of_record)
# ORDER BY HOUR(time_of_record) ASC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 14 rows affected.
# [(6, Decimal('149')),
#  (7, Decimal('149')),
#  (8, Decimal('149')),
#  (9, Decimal('49')),
#  (10, Decimal('48')),
#  (11, Decimal('46')),
#  (12, Decimal('47')),
#  (13, Decimal('47')),
#  (14, Decimal('47')),
#  (15, Decimal('48')),
#  (16, Decimal('47')),
#  (17, Decimal('149')),
#  (18, Decimal('147')),
#  (19, Decimal('168'))]

# %% [markdown]
# I don't know about you, but the hour number is difficult to interpret. A format like 06:00 will be easier to read, so let's use that.

# %% [markdown]
# **Hint** *To format time into a specific display format, we can use `TIME_FORMAT(time, format)`. It takes a time data field and
# converts it into a format like %H:00 which is easy to read. `HOUR(time_of_record)` gives us an integer value of the hour of the day, that won't work
# with `TIME_FORMAT()`, so we need to use `TIME(time_of_record)` instead*.

# %%
# %%sql
# SELECT
#     TIME(time_of_record) as time
# FROM visits
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 10 rows affected.
# [(datetime.timedelta(seconds=33000),),
#  (datetime.timedelta(seconds=33420),),
#  (datetime.timedelta(seconds=34560),),
#  (datetime.timedelta(seconds=35580),),
#  (datetime.timedelta(seconds=36660),),
#  (datetime.timedelta(seconds=37020),),
#  (datetime.timedelta(seconds=37080),),
#  (datetime.timedelta(seconds=37680),),
#  (datetime.timedelta(seconds=38220),),
#  (datetime.timedelta(seconds=39480),)]

# %%
# %%sql
# SELECT
#     TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
#     ROUND(AVG(time_in_queue)) as avg_queue_time
# FROM visits
# GROUP BY 1
# ORDER BY 1 ASC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 14 rows affected.
# [('06:00', Decimal('149')),
#  ('07:00', Decimal('149')),
#  ('08:00', Decimal('149')),
#  ('09:00', Decimal('49')),
#  ('10:00', Decimal('48')),
#  ('11:00', Decimal('46')),
#  ('12:00', Decimal('47')),
#  ('13:00', Decimal('47')),
#  ('14:00', Decimal('47')),
#  ('15:00', Decimal('48')),
#  ('16:00', Decimal('47')),
#  ('17:00', Decimal('149')),
#  ('18:00', Decimal('147')),
#  ('19:00', Decimal('168'))]

# %% [markdown]
# ### 6.32.Creating a pivot table in SQL
# Pivot tables are not widely used in SQL, despite being useful for interpreting results. So there are no built-in functions to do this for us. Sometimes
# the dataset is just so massive that it is the only option. *(For rows, we will use the hour of the day in that nice format, and then make each column a different day!)*
# <br>To filter a row we use `WHERE`, but using `CASE()` in `SELECT` can filter columns. We can use a `CASE()` function for each day to separate the `queue time` column into a column for each day. Let’s begin by only focusing on Sunday. So, when a row's `DAYNAME(time_of_record)` is Sunday, we
# make that value equal to `time_in_queue`, and `NULL` for any days.

# %%
# %%sql
# SELECT
#     TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
#     DAYNAME(time_of_record),
#     CASE
#         WHEN DAYNAME(time_of_record) = 'Sunday'
#         THEN time_in_queue
#         ELSE NULL
#     END AS Sunday
# FROM visits
# WHERE time_in_queue != 0 # This excludes other sources with 0 queue times.
# LIMIT 200;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 200 rows affected.
# [('09:00', 'Friday', None),
#  ('09:00', 'Friday', None),
#  ('10:00', 'Friday', None),
#  ('10:00', 'Friday', None),
#  ('11:00', 'Friday', None),
#  ('11:00', 'Friday', None),
#  ('12:00', 'Friday', None),
#  ('12:00', 'Friday', None),
#  ('13:00', 'Friday', None),
#  ('13:00', 'Friday', None),
#  ('13:00', 'Friday', None),
#  ('14:00', 'Friday', None),
#  ('14:00', 'Friday', None),
#  ('15:00', 'Friday', None),
#  ('16:00', 'Friday', None),
#  ('07:00', 'Saturday', None),
#  ('07:00', 'Saturday', None),
#  ('09:00', 'Saturday', None),
#  ('11:00', 'Saturday', None),
#  ('13:00', 'Saturday', None),
#  ('09:00', 'Sunday', 103),
#  ('11:00', 'Sunday', 39),
#  ('12:00', 'Sunday', 112),
#  ('14:00', 'Sunday', 30),
#  ('14:00', 'Sunday', 104),
#  ('07:00', 'Monday', None),
#  ('09:00', 'Monday', None),
#  ('11:00', 'Monday', None),
#  ('11:00', 'Monday', None),
#  ('12:00', 'Monday', None),
#  ('12:00', 'Monday', None),
#  ('14:00', 'Monday', None),
#  ('14:00', 'Monday', None),
#  ('15:00', 'Monday', None),
#  ('15:00', 'Monday', None),
#  ('16:00', 'Monday', None),
#  ('16:00', 'Monday', None),
#  ('18:00', 'Monday', None),
#  ('07:00', 'Tuesday', None),
#  ('08:00', 'Tuesday', None),
#  ('09:00', 'Tuesday', None),
#  ('09:00', 'Tuesday', None),
#  ('10:00', 'Tuesday', None),
#  ('10:00', 'Tuesday', None),
#  ('10:00', 'Tuesday', None),
#  ('10:00', 'Tuesday', None),
#  ('11:00', 'Tuesday', None),
#  ('12:00', 'Tuesday', None),
#  ('13:00', 'Tuesday', None),
#  ('13:00', 'Tuesday', None),
#  ('13:00', 'Tuesday', None),
#  ('14:00', 'Tuesday', None),
#  ('14:00', 'Tuesday', None),
#  ('15:00', 'Tuesday', None),
#  ('16:00', 'Tuesday', None),
#  ('16:00', 'Tuesday', None),
#  ('16:00', 'Tuesday', None),
#  ('16:00', 'Tuesday', None),
#  ('17:00', 'Tuesday', None),
#  ('06:00', 'Wednesday', None),
#  ('07:00', 'Wednesday', None),
#  ('09:00', 'Wednesday', None),
#  ('09:00', 'Wednesday', None),
#  ('09:00', 'Wednesday', None),
#  ('09:00', 'Wednesday', None),
#  ('10:00', 'Wednesday', None),
#  ('18:00', 'Sunday', 87),
#  ('18:00', 'Sunday', 22),
#  ('18:00', 'Sunday', 59),
#  ('18:00', 'Sunday', 94),
#  ('06:00', 'Monday', None),
#  ('06:00', 'Monday', None),
#  ('06:00', 'Monday', None),
#  ('06:00', 'Monday', None),
#  ('06:00', 'Monday', None),
#  ('08:00', 'Monday', None),
#  ('08:00', 'Monday', None),
#  ('09:00', 'Monday', None),
#  ('10:00', 'Monday', None),
#  ('10:00', 'Monday', None),
#  ('10:00', 'Monday', None),
#  ('10:00', 'Monday', None),
#  ('11:00', 'Monday', None),
#  ('11:00', 'Monday', None),
#  ('11:00', 'Monday', None),
#  ('12:00', 'Monday', None),
#  ('12:00', 'Monday', None),
#  ('12:00', 'Monday', None),
#  ('13:00', 'Monday', None),
#  ('14:00', 'Monday', None),
#  ('14:00', 'Monday', None)]

# %% [markdown]
# By adding `AVG()` around the `CASE()` function, we calculate the average, but since all of the other days' values are 0, we get an average for Sunday
# only, rounded to 0 decimals. To aggregate by the hour, we can group the data by `hour_of_day`, and to make the table chronological, we also order
# by `hour_of_day`.

# %%
# %%sql
# SELECT
#     TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
# # Sunday
#     ROUND(AVG(
#         CASE
#             WHEN DAYNAME(time_of_record) = 'Sunday'
#             THEN time_in_queue ELSE NULL
#         END
#     ),0) AS Sunday,
# # Monday
#     ROUND(AVG(
#         CASE
#             WHEN DAYNAME(time_of_record) = 'Monday'
#             THEN time_in_queue ELSE NULL
#         END
#     ),0) AS Monday,
# # Tuesday
#     ROUND(AVG(
#         CASE
#             WHEN DAYNAME(time_of_record) = 'Tuesday'
#             THEN time_in_queue ELSE NULL
#         END
#     ),0) as Tuesday,
# # Wednesday
#     ROUND(AVG(
#         CASE
#             WHEN DAYNAME(time_of_record) = 'Wednesday'
#             THEN time_in_queue ELSE NULL
#         END
#     ),0) as Wednesday,
# # Thursday
#     ROUND(AVG(
#         CASE
#             WHEN DAYNAME(time_of_record) = 'Thursday'
#             THEN time_in_queue ELSE NULL
#         END
#     ),0) as Thursday,
# # Friday
#     ROUND(AVG(
#         CASE
#             WHEN DAYNAME(time_of_record) = 'Friday'
#             THEN time_in_queue ELSE NULL
#         END
#     ),0) as Friday,
# # Saturday
#     ROUND(AVG(
#         CASE
#             WHEN DAYNAME(time_of_record) = 'Saturday'
#             THEN time_in_queue ELSE NULL
#         END
#     ),0) as Saturday
# FROM visits
# WHERE time_in_queue != 0 # This excludes other sources with 0 queue times
# GROUP BY hour_of_day
# ORDER BY hour_of_day;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 14 rows affected.
# [('06:00', Decimal('79'), Decimal('190'), Decimal('134'), Decimal('112'), Decimal('134'), Decimal('153'), Decimal('247')),
#  ('07:00', Decimal('82'), Decimal('186'), Decimal('128'), Decimal('111'), Decimal('139'), Decimal('156'), Decimal('247')),
#  ('08:00', Decimal('86'), Decimal('183'), Decimal('130'), Decimal('119'), Decimal('129'), Decimal('153'), Decimal('247')),
#  ('09:00', Decimal('84'), Decimal('127'), Decimal('105'), Decimal('94'), Decimal('99'), Decimal('107'), Decimal('252')),
#  ('10:00', Decimal('83'), Decimal('119'), Decimal('99'), Decimal('89'), Decimal('95'), Decimal('112'), Decimal('259')),
#  ('11:00', Decimal('78'), Decimal('115'), Decimal('102'), Decimal('86'), Decimal('99'), Decimal('104'), Decimal('236')),
#  ('12:00', Decimal('78'), Decimal('115'), Decimal('97'), Decimal('88'), Decimal('96'), Decimal('109'), Decimal('239')),
#  ('13:00', Decimal('81'), Decimal('122'), Decimal('97'), Decimal('98'), Decimal('101'), Decimal('115'), Decimal('242')),
#  ('14:00', Decimal('83'), Decimal('127'), Decimal('104'), Decimal('92'), Decimal('96'), Decimal('110'), Decimal('244')),
#  ('15:00', Decimal('83'), Decimal('126'), Decimal('104'), Decimal('88'), Decimal('92'), Decimal('110'), Decimal('248')),
#  ('16:00', Decimal('83'), Decimal('127'), Decimal('99'), Decimal('90'), Decimal('99'), Decimal('109'), Decimal('251')),
#  ('17:00', Decimal('79'), Decimal('181'), Decimal('135'), Decimal('121'), Decimal('129'), Decimal('151'), Decimal('251')),
#  ('18:00', Decimal('80'), Decimal('174'), Decimal('122'), Decimal('113'), Decimal('132'), Decimal('158'), Decimal('240')),
#  ('19:00', Decimal('127'), Decimal('159'), Decimal('145'), Decimal('176'), Decimal('137'), Decimal('103'), Decimal('282'))]

# %% [markdown]
# See if you can spot these patterns:
# 1. Queues are very long on a Monday morning and Monday evening as people rush to get water.
# 2. Wednesday has the lowest queue times, but long queues on Wednesday evening.
# 3. People have to queue pretty much twice as long on Saturdays compared to the weekdays. It looks like people spend their Saturdays queueing
# for water, perhaps for the week's supply?
# 4. The shortest queues are on Sundays, and this is a cultural thing. The people of Maji Ndogo prioritise family and religion, so Sundays are spent
# with family and friends. <br>**NOTE** *By understanding `CASE`, we could
# build a complex query that aggregates our data in a format that is very easy to understand*.

# %% [markdown]
# ## 7. Reporting Insights
# **Assembling our insights to a story.**

# %% [markdown]
# ### 7.38. Water Accessibility and Infrastructure Summary Report
# This survey aimed to identify the water sources people use and determine both the total and average number of users for each source.
# Additionally, it examined the duration citizens typically spend in queues to access water.

# %% [markdown]
# ### 7.38 Insights
# 1. Most water sources are rural.
# 2. 43% of our people are using shared taps. 2000 people often share one tap.
# 3. 31% of our population has water infrastructure in their homes, but within that group, 45% face non-functional systems due to issues with pipes,
# pumps, and reservoirs.
# 4. 18% of our people are using wells of which, but within that, only 28% are clean.
# 5. Our citizens often face long wait times for water, averaging more than 120 minutes.
# 6. In terms of queues:
# - Queues are very long on Saturdays.
# - Queues are longer in the mornings and evenings.
# - Wednesdays and Sundays have the shortest queues.

# %% [markdown]
# ### 7.39. Start of our plan
# <br>We have started thinking about a plan:
# 1. We want to focus our efforts on improving the water sources that affect the most people.
# - Most people will benefit if we improve the shared taps first.
# - Wells are a good source of water, but many are contaminated. Fixing this will benefit a lot of people.
# - Fixing existing infrastructure will help many people. If they have running water again, they won't have to queue, thereby shorting queue times for
# others. So we can solve two problems at once.
# - Installing taps in homes will stretch our resources too thin, so for now, if the queue times are low, we won't improve that source.
# 2. Most water sources are in rural areas. We need to ensure our teams know this as this means they will have to make these repairs/upgrades in
# rural areas where road conditions, supplies, and labour are harder challenges to overcome.

# %% [markdown]
# ### 7.40. Practical solutions
# 1. If communities are using **rivers**, we can dispatch trucks to those regions to provide water temporarily in the short term, while we send out
# crews to drill for wells, providing a more permanent solution.
# 2. If communities are using **wells**, we can install filters to purify the water. For wells with **biological** contamination, we can **install UV filters** that kill microorganisms, and for *polluted wells*, we can install **reverse osmosis** filters. In the long term, we need to figure out why these sources
# are polluted.
# 3. For **shared taps**, in the short term, we can send additional water tankers to the busiest taps, on the busiest days. We can use the queue time
# pivot table we made to send tankers at the busiest times. Meanwhile, we can start the work on **installing extra taps** where they are needed.
# According to UN standards, the maximum acceptable wait time for water is 30 minutes. With this in mind, we aim to **install taps** to get
# **queue times below 30 min**.
# 4. **Shared taps** with **short queue times** (< 30 min) represent a logistical challenge to further reduce waiting times. The most effective solution,
# installing taps in homes, is resource-intensive and better suited as a long-term goal.
# 5. **Addressing broken infrastructure** offers a significant impact even with just a single intervention. It is expensive to fix, but so **many people**
# can **benefit** from repairing one facility. For example, fixing a reservoir or pipe that multiple taps are connected to. We will have to find the
# commonly affected areas though to see where the problem actually is.

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Q1.
# Which SQL query will produce the date format "DD Month YYYY" from the `time_of_record` column in the `visits`
# table, as a single column? ***Note**: `Monthname()` acts in a similar way to `DAYNAME()`*.

# %%
# %%sql
# SELECT * FROM visits LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40)]

# %%
# %%sql
# SELECT
#     CONCAT(DAY(time_of_record),' ', MONTHNAME(time_of_record), ' ', YEAR(time_of_record)) as date
# FROM visits
# LIMIT 200;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 200 rows affected.
# [('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('2 January 2021',),
#  ('2 January 2021',),
#  ('2 January 2021',),
#  ('2 January 2021',),
#  ('2 January 2021',),
#  ('3 January 2021',),
#  ('3 January 2021',),
#  ('3 January 2021',),
#  ('3 January 2021',),
#  ('3 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('4 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('5 January 2021',),
#  ('6 January 2021',),
#  ('6 January 2021',),
#  ('6 January 2021',),
#  ('6 January 2021',)]

# %% [markdown]
# ### Q2
# You are working with an SQL query designed to calculate the Annual Rate of Change (ARC) for basic rural water services:
# <br>SELECT `name`, `wat_bas_r` - LAG(`wat_bas_r`) OVER (PARTITION BY`(a)` ORDER BY `(b)`)
# <br>FROM `global_water_access`
# <br>ORDER BY `name`;
# <br>To accomplish this task, what should you use for placeholders `(a)` and `(b)`?

# %% [markdown]
# **Solution**
# <br>Use **name** for grouping and **year** for
# sorting.

# %% [markdown]
# ### Q3.
# What are the names of the two worst-performing employees who visited the fewest sites, and how many sites
# did the worst-performing employee visit? *Modify your queries from the “Honouring the workers” section*

# %%
# %%sql
# SELECT
#     assigned_employee_id,
#     COUNT(visit_count) as number_of_visits
# FROM visits
# GROUP BY assigned_employee_id
# ORDER BY 2 ASC
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3 rows affected.
# [(20, 15), (22, 143), (44, 218)]

# %%
# %%sql
# SELECT
#     assigned_employee_id,
#     employee_name,
#     email,
#     phone_number
# FROM employee
# WHERE assigned_employee_id IN (20,22,44);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3 rows affected.
# [(20, 'Kunto Asha', 'kunto.asha@ndogowater.gov', '+99176320477'),
#  (22, 'Lesedi Kofi', 'lesedi.kofi@ndogowater.gov', '+99611183730'),
#  (44, 'Wambui Jabali', 'wambui.jabali@ndogowater.gov', '+99269319001')]

# %% [markdown]
# ### Q4
# What does the following query do?

# %%
# %%sql
# SELECT
#     location_id,
#     time_in_queue,
#     AVG(time_in_queue) OVER (
#         PARTITION BY location_id ORDER BY visit_count) AS total_avg_queue_time
# FROM visits
# WHERE visit_count > 1 # Only shared taps were visited > 1
# ORDER BY location_id, time_of_record
# LIMIT 200;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
#
#  ('AkHa00263', 161, Decimal('203.0000')),
#  ('AkHa00263', 118, Decimal('188.8333')),
#  ('AkHa00263', 197, Decimal('190.0000')),
#  ('AkHa00373', 133, Decimal('133.0000')),
#  ('AkHa00373', 369, Decimal('251.0000')),
#  ('AkHa00373', 96, Decimal('199.3333')),
#  ('AkHa00373', 125, Decimal('180.7500')),
#  ('AkHa00373', 201, Decimal('184.8000')),
#  ('AkHa00373', 88, Decimal('168.6667')),
#  ('AkHa00373', 107, Decimal('159.8571')),
#  ('AkHa00460', 257, Decimal('257.0000')),
#  ('AkHa00460', 215, Decimal('236.0000')),
#  ('AkHa00460', 96, Decimal('189.3333')),
#  ('AkHa00460', 295, Decimal('215.7500')),
#  ('AkHa00460', 430, Decimal('258.6000')),
#  ('AkHa00460', 58, Decimal('225.1667')),
#  ('AkHa00460', 120, Decimal('210.1429')),
#  ('AkHa00548', 115, Decimal('115.0000')),
#  ('AkHa00548', 60, Decimal('87.5000')),
#  ('AkHa00548', 79, Decimal('84.6667')),
#  ('AkHa00548', 83, Decimal('84.2500')),
#  ('AkHa00548', 44, Decimal('76.2000')),
#  ('AkHa00548', 93, Decimal('79.0000')),
#  ('AkHa00548', 69, Decimal('77.5714')),
#  ('AkHa00575', 181, Decimal('181.0000')),
#  ('AkHa00575', 496, Decimal('338.5000')),
#  ('AkHa00575', 111, Decimal('262.6667')),
#  ('AkHa00575', 368, Decimal('289.0000')),
#  ('AkHa00575', 94, Decimal('250.0000')),
#  ('AkHa00575', 92, Decimal('223.6667')),
#  ('AkHa00575', 114, Decimal('208.0000')),
#  ('AkHa00577', 39, Decimal('39.0000')),
#  ('AkHa00577', 66, Decimal('52.5000')),
#  ('AkHa00577', 77, Decimal('60.6667')),
#  ('AkHa00577', 88, Decimal('67.5000')),
#  ('AkHa00577', 143, Decimal('82.6000')),
#  ('AkHa00577', 51, Decimal('77.3333')),
#  ('AkHa00577', 66, Decimal('75.7143')),
#  ('AkHa00668', 147, Decimal('147.0000')),
#  ('AkHa00668', 353, Decimal('250.0000')),
#  ('AkHa00668', 125, Decimal('208.3333')),
#  ('AkHa00668', 268, Decimal('223.2500')),
#  ('AkHa00668', 176, Decimal('213.8000')),
#  ('AkHa00668', 228, Decimal('216.1667')),
#  ('AkHa00668', 255, Decimal('221.7143')),
#  ('AkHa00743', 20, Decimal('20.0000')),
#  ('AkHa00743', 20, Decimal('20.0000')),
#  ('AkHa00743', 42, Decimal('27.3333')),
#  ('AkHa00743', 52, Decimal('33.5000')),
#  ('AkHa00743', 53, Decimal('37.4000')),
#  ('AkHa00743', 22, Decimal('34.8333')),
#  ('AkHa00743', 54, Decimal('37.5714')),
#  ('AkHa00756', 45, Decimal('45.0000')),
#  ('AkHa00756', 51, Decimal('48.0000')),
#  ('AkHa00756', 54, Decimal('50.0000')),
#  ('AkHa00756', 35, Decimal('46.2500')),
#  ('AkHa00756', 39, Decimal('44.8000')),
#  ('AkHa00756', 63, Decimal('47.8333')),
#  ('AkHa00756', 37, Decimal('46.2857')),
#  ('AkKi00881', 178, Decimal('178.0000')),
#  ('AkKi00881', 139, Decimal('158.5000')),
#  ('AkKi00881', 172, Decimal('163.0000')),
#  ('AkKi00881', 338, Decimal('206.7500')),
#  ('AkKi00881', 502, Decimal('265.8000')),
#  ('AkKi00881', 87, Decimal('236.0000')),
#  ('AkKi00881', 274, Decimal('241.4286')),
#  ('AkKi00890', 297, Decimal('297.0000')),
#  ('AkKi00890', 113, Decimal('205.0000')),
#  ('AkKi00890', 169, Decimal('193.0000')),
#  ('AkKi00890', 210, Decimal('197.2500')),
#  ('AkKi00890', 83, Decimal('174.4000')),
#  ('AkKi00890', 161, Decimal('172.1667')),
#  ('AkKi00890', 93, Decimal('160.8571')),
#  ('AkKi00911', 53, Decimal('53.0000')),
#  ('AkKi00911', 23, Decimal('38.0000')),
#  ('AkKi00911', 31, Decimal('35.6667')),
#  ('AkKi00911', 58, Decimal('41.2500')),
#  ('AkKi00911', 23, Decimal('37.6000')),
#  ('AkKi00911', 39, Decimal('37.8333')),
#  ('AkKi00911', 71, Decimal('42.5714')),
#  ('AkKi00924', 131, Decimal('131.0000')),
#  ('AkKi00924', 169, Decimal('150.0000')),
#  ('AkKi00924', 236, Decimal('178.6667')),
#  ('AkKi00924', 132, Decimal('167.0000')),
#  ('AkKi00924', 236, Decimal('180.8000')),
#  ('AkKi00924', 285, Decimal('198.1667')),
#  ('AkKi00924', 209, Decimal('199.7143')),
#  ('AkKi00933', 156, Decimal('156.0000')),
#  ('AkKi00933', 275, Decimal('215.5000')),
#  ('AkKi00933', 91, Decimal('174.0000')),
#  ('AkKi00933', 251, Decimal('193.2500')),
#  ('AkKi00933', 143, Decimal('183.2000')),
#  ('AkKi00933', 141, Decimal('176.1667')),
#  ('AkKi00933', 172, Decimal('175.5714')),
#  ('AkKi00997', 64, Decimal('64.0000')),
#  ('AkKi00997', 86, Decimal('75.0000')),
#  ('AkKi00997', 159, Decimal('103.0000')),
#  ('AkKi00997', 39, Decimal('87.0000')),
#  ('AkKi00997', 202, Decimal('110.0000')),
#  ('AkKi00997', 122, Decimal('112.0000')),
#  ('AkKi00997', 122, Decimal('113.4286')),
#  ('AkKi01061', 188, Decimal('188.0000')),
#  ('AkKi01061', 98, Decimal('143.0000')),
#  ('AkKi01061', 270, Decimal('185.3333')),
#  ('AkKi01061', 128, Decimal('171.0000')),
#  ('AkKi01061', 98, Decimal('156.4000')),
#  ('AkKi01061', 148, Decimal('155.0000')),
#  ('AkKi01061', 66, Decimal('142.2857')),
#  ('AkKi01082', 150, Decimal('150.0000')),
#  ('AkKi01082', 48, Decimal('99.0000')),
#  ('AkKi01082', 51, Decimal('83.0000')),
#  ('AkKi01082', 42, Decimal('72.7500')),
#  ('AkKi01082', 24, Decimal('63.0000')),
#  ('AkKi01082', 55, Decimal('61.6667')),
#  ('AkKi01082', 74, Decimal('63.4286')),
#  ('AkKi01104', 176, Decimal('176.0000')),
#  ('AkKi01104', 308, Decimal('242.0000')),
#  ('AkKi01104', 174, Decimal('219.3333')),
#  ('AkKi01104', 218, Decimal('219.0000')),
#  ('AkKi01104', 101, Decimal('195.4000')),
#  ('AkKi01104', 151, Decimal('188.0000')),
#  ('AkKi01104', 113, Decimal('177.2857')),
#  ('AkKi01158', 189, Decimal('189.0000')),
#  ('AkKi01158', 220, Decimal('204.5000')),
#  ('AkKi01158', 369, Decimal('259.3333')),
#  ('AkKi01158', 113, Decimal('222.7500')),
#  ('AkKi01158', 124, Decimal('203.0000')),
#  ('AkKi01158', 173, Decimal('198.0000')),
#  ('AkKi01158', 180, Decimal('195.4286')),
#  ('AkKi01192', 149, Decimal('149.0000')),
#  ('AkKi01192', 145, Decimal('147.0000')),
#  ('AkKi01192', 253, Decimal('182.3333')),
#  ('AkKi01192', 276, Decimal('205.7500')),
#  ('AkKi01192', 358, Decimal('236.2000')),
#  ('AkKi01192', 62, Decimal('207.1667')),
#  ('AkKi01192', 278, Decimal('217.2857')),
#  ('AkKi01265', 520, Decimal('520.0000')),
#  ('AkKi01265', 161, Decimal('340.5000')),
#  ('AkKi01265', 302, Decimal('327.6667')),
#  ('AkKi01265', 111, Decimal('273.5000')),
#  ('AkKi01265', 178, Decimal('254.4000')),
#  ('AkKi01265', 267, Decimal('256.5000')),
#  ('AkKi01265', 148, Decimal('241.0000')),
#  ('AkKi01372', 93, Decimal('93.0000')),
#  ('AkKi01372', 109, Decimal('101.0000')),
#  ('AkKi01372', 187, Decimal('129.6667')),
#  ('AkKi01372', 259, Decimal('162.0000'))]

# %% [markdown]
# **Explanation**
# <br>It computes an average queue time for shared taps,
# that is updated each time a source is visited.
# <br>*This option accurately captures what the query does. It computes a running average of queue times for shared taps (due to visit_count > 1), partitioned by `location_id`, and this average is updated for each visit based on the `ORDER BY visit_count`*.

# %% [markdown]
# ### Q5
# One of our employees, Farai Nia, lives at 33 Angelique Kidjo Avenue. What would be the result if we `TRIM()` her
# address?<br>
# TRIM('33 Angelique Kidjo Avenue ')

# %%
# %%sql
# SELECT TRIM('33 Angelique Kidjo Avenue ') as trimmed_employee
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 1 rows affected.
# [('33 Angelique Kidjo Avenue',)]

# %% [markdown]
# **Explanation**<br>
# The `TRIM()` function removes the leading and trailing spaces from the string '33 Angelique Kidjo Avenue '. The spaces within the address are untouched, making the correct output ‘33 Angelique Kidjo Avenue’.

# %% [markdown]
# ### Q6
# How many employees live in Dahabu? *Rely on one of the queries we used in the project to answer this.*

# %%
# %%sql
# SELECT * FROM employee LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 10 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900', 'malachi.mavuso@ndogowater.gov', '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640', 'cheche.buhle@ndogowater.gov', '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor'),
#  (5, 'Zuriel Matembo', '+99034075111', 'zuriel.matembo@ndogowater.gov', '26 Bahari Ya Faraja Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (6, 'Deka Osumare', '+99379364631', 'deka.osumare@ndogowater.gov', '104 Kenyatta Street', 'Akatsi', 'Rural', 'Field Surveyor'),
#  (7, 'Lalitha Kaburi', '+99681623240', 'lalitha.kaburi@ndogowater.gov', '145 Sungura Amanpour Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (8, 'Enitan Zuri', '+99248509202', 'enitan.zuri@ndogowater.gov', '117 Kampala Road', 'Hawassa', 'Zanzibar', 'Field Surveyor'),
#  (10, 'Farai Nia', '+99570082739', 'farai.nia@ndogowater.gov', '33 Angélique Kidjo Avenue', 'Amanzi', 'Dahabu', 'Field Surveyor')]

# %%
# %%sql
# SELECT
#     COUNT(DISTINCT(employee_name)) as dahabu_employees
# FROM employee
# WHERE town_name LIKE ('Dahabu');
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 1 rows affected.
# [(6,)]

# %% [markdown]
# ### Q7
# How many employees live in Harare, Kilimani? *Modify one of your queries from the project to answer this
# question*

# %%
# %%sql
# SELECT
#     COUNT(DISTINCT(employee_name)) as harare_kilimani_employees
# FROM employee
# WHERE town_name LIKE ('Harare')
#     AND province_name LIKE ('Kilimani');
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 1 rows affected.
# [(2,)]

# %% [markdown]
# ### Q8
# How many people share a well on average? *Round your answer to 0 decimals*

# %%
# %%sql
# SELECT * FROM water_source LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 5 rows affected.
# [('AkHa00000224', 'tap_in_home', 956),
#  ('AkHa00001224', 'tap_in_home_broken', 930),
#  ('AkHa00002224', 'tap_in_home_broken', 486),
#  ('AkHa00003224', 'well', 364),
#  ('AkHa00004224', 'tap_in_home_broken', 942)]

# %%
# %%sql
# SELECT
#     ROUND(AVG(number_of_people_served)) as avg_people_using_well_water_source
# FROM water_source
# WHERE type_of_water_source LIKE ('well');
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 1 rows affected.
# [(Decimal('279'),)]

# %% [markdown]
# ### Q9
# Consider the query we used to calculate the total number of people served:
# <br>Which lines of code will calculate the total number of people using some sort of tap?

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     SUM(number_of_people_served) as population_served
# FROM water_source
# WHERE type_of_water_source LIKE '%tap%'
# GROUP BY 1
# ORDER BY population_served;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_servicesds
# 3 rows affected.
# [('tap_in_home_broken', Decimal('3799720')),
#  ('tap_in_home', Decimal('4678880')),
#  ('shared_tap', Decimal('11945272'))]

# %% [markdown]
# ### Q10
# Use the pivot table we created to answer the following question. What are the average queue times for the following times?
# <br>Saturday from 12:00 to 13:00
# <br>Tuesday from 18:00 to 19:00
# <br>Sunday from 09:00 to 10:00

# %% [markdown]
# **Solution:**
# <br>Saturday: 239, Tuesday: 122, Sunday: 84

# %% [markdown]
# **Explanation:**
# <br>Saturday: 242, Tuesday: 145, Sunday: 83 are incorrect because the queue times for Saturday and Tuesday and Sunday are taken from 13:00, 18:00 and 10:00 respectively. This tests if you understand the correct time stamps to reference

# %% [markdown]
# <h2 style='text-align: center;'> **THE END**
